# %% [markdown]
# # Alignment metric

# %% [markdown]
# ## Numeral seq completion:

# %%
texts = ['Van done in 1. Hat done in 2. Ring done in 3. Desk done in 4. Sun done in', 'Ice done in 2. Snow done in 3. Watch done in 4. Sun done in 5. Table done in', 'Ring done in 3. Moon done in 4. Queen done in 5. Book done in 6. Rose done in', 'Queen done in 4. Oil done in 5. Rose done in 6. Desk done in 7. Car done in', 'Light done in 5. Arm done in 6. Road done in 7. Book done in 8. Ice done in', 'Ball done in 6. Cow done in 7. Book done in 8. Rose done in 9. Key done in', 'Road done in 7. Key done in 8. Ocean done in 9. Key done in 10. Queen done in', 'House done in 8. Rose done in 9. Key done in 10. Hat done in 11. Van done in', 'Ring done in 1. Car done in 2. Apple done in 3. Pear done in 4. Moon done in', 'Star done in 2. Sun done in 3. Road done in 4. Queen done in 5. Box done in', 'Hill done in 3. Ant done in 4. Apple done in 5. House done in 6. Hat done in', 'Chair done in 4. Van done in 5. Orange done in 6. Queen done in 7. Zip done in', 'Gate done in 5. Desk done in 6. Wolf done in 7. Rain done in 8. Flag done in', 'Queen done in 6. House done in 7. Light done in 8. Cat done in 9. Moon done in', 'Zip done in 7. Car done in 8. Ring done in 9. Hand done in 10. Fish done in', 'Snake done in 8. Queen done in 9. Window done in 10. Ear done in 11. Orange done in', 'Ice done in 1. Sand done in 2. Desk done in 3. Van done in 4. Hat done in', 'Camera done in 2. Watch done in 3. Dog done in 4. Book done in 5. Desk done in', 'Rain done in 3. Dog done in 4. Rat done in 5. Nut done in 6. Ocean done in', 'Night done in 4. Hat done in 5. Wall done in 6. Book done in 7. Tree done in', 'Gate done in 5. Chair done in 6. Ring done in 7. Hill done in 8. Car done in', 'Ax done in 6. Fan done in 7. Cat done in 8. Ring done in 9. Ring done in', 'Rose done in 7. Night done in 8. Van done in 9. Orange done in 10. Apple done in', 'Orange done in 8. Ear done in 9. Book done in 10. Ring done in 11. Bird done in', 'Ball done in 1. Wind done in 2. Wallet done in 3. Tree done in 4. Sand done in', 'Table done in 2. Jam done in 3. Apple done in 4. Pear done in 5. Ice done in', 'Gate done in 3. Train done in 4. Hat done in 5. Fan done in 6. Key done in', 'Window done in 4. Desk done in 5. Year done in 6. Van done in 7. Camera done in', 'Car done in 5. Watch done in 6. Oil done in 7. Queen done in 8. Fan done in', 'Mouse done in 6. Rose done in 7. Table done in 8. Clock done in 9. Queen done in', 'Year done in 7. Wheel done in 8. Wolf done in 9. Arm done in 10. Ax done in', 'Key done in 8. Ring done in 9. Night done in 10. Fan done in 11. Clock done in', 'Glass done in 1. Key done in 2. Nut done in 3. Rat done in 4. Van done in', 'Star done in 2. Pear done in 3. Bug done in 4. Bird done in 5. Ring done in', 'Road done in 3. Wind done in 4. Rat done in 5. Wolf done in 6. Map done in', 'Car done in 4. Ant done in 5. Rose done in 6. Van done in 7. Wolf done in', 'Zip done in 5. Hat done in 6. Wind done in 7. Rain done in 8. Car done in', 'Ring done in 6. Light done in 7. Jar done in 8. Dog done in 9. Fish done in', 'Bug done in 7. Key done in 8. Gate done in 9. Orange done in 10. Ring done in', 'Flag done in 8. Fire done in 9. Pear done in 10. Ax done in 11. Ear done in', 'Ring done in 1. Flag done in 2. Queen done in 3. Map done in 4. Camera done in', 'Desk done in 2. Fire done in 3. Desk done in 4. Road done in 5. Watch done in', 'Queen done in 3. House done in 4. Flag done in 5. Tree done in 6. Ring done in', 'Desk done in 4. Window done in 5. Fish done in 6. Jar done in 7. Hat done in', 'Snake done in 5. Key done in 6. Glass done in 7. Van done in 8. House done in', 'Camera done in 6. Year done in 7. Rose done in 8. Map done in 9. Fire done in', 'Rose done in 7. Snake done in 8. Corn done in 9. Desk done in 10. Zip done in', 'Table done in 8. Key done in 9. Eye done in 10. Van done in 11. Key done in', 'Star done in 1. Hat done in 2. Star done in 3. Eye done in 4. Gold done in', 'Gate done in 2. Queen done in 3. Camera done in 4. Zip done in 5. Ocean done in', 'Fan done in 3. Corn done in 4. Apple done in 5. Van done in 6. Cat done in', 'Key done in 4. Gold done in 5. Star done in 6. Queen done in 7. Arm done in', 'Van done in 5. Snake done in 6. Car done in 7. Star done in 8. Watch done in', 'Jar done in 6. Flag done in 7. Window done in 8. Sun done in 9. Van done in', 'Wolf done in 7. Watch done in 8. Ring done in 9. Desk done in 10. Car done in', 'Cow done in 8. Tree done in 9. Book done in 10. Wall done in 11. Flag done in', 'Van done in 1. Wall done in 2. Ring done in 3. Car done in 4. Key done in', 'Jar done in 2. Wallet done in 3. Fish done in 4. Watch done in 5. Orange done in', 'Watch done in 3. Orange done in 4. Table done in 5. Corn done in 6. Van done in', 'Lake done in 4. Star done in 5. Fan done in 6. Fan done in 7. Night done in', 'Fan done in 5. Ball done in 6. Desk done in 7. Jam done in 8. Tree done in', 'Key done in 6. Jar done in 7. Night done in 8. Fish done in 9. Fan done in', 'Ice done in 7. Rose done in 8. Wall done in 9. Road done in 10. Window done in', 'Tree done in 8. Hill done in 9. Wall done in 10. Queen done in 11. Desk done in', 'Gold done in 1. King done in 2. Queen done in 3. Desk done in 4. Night done in', 'Van done in 2. Sand done in 3. Tree done in 4. Car done in 5. Cow done in', 'Pear done in 3. Eye done in 4. Lake done in 5. Fan done in 6. Light done in', 'Jam done in 4. Road done in 5. Corn done in 6. Ice done in 7. Pen done in', 'Iron done in 5. Ring done in 6. Star done in 7. Van done in 8. Star done in', 'Bird done in 6. Wheel done in 7. Cat done in 8. Desk done in 9. Desk done in', 'Fish done in 7. Gold done in 8. King done in 9. Ax done in 10. Jam done in', 'Desk done in 8. House done in 9. Cow done in 10. Hill done in 11. Gate done in', 'Nut done in 1. Light done in 2. Sand done in 3. Wall done in 4. Key done in', 'Tree done in 2. Fan done in 3. Car done in 4. Desk done in 5. Ring done in', 'Orange done in 3. Ocean done in 4. Sun done in 5. Bug done in 6. Queen done in', 'Orange done in 4. House done in 5. Watch done in 6. Corn done in 7. Ring done in', 'Wind done in 5. Orange done in 6. Rose done in 7. Zip done in 8. Queen done in', 'Iron done in 6. Cat done in 7. Glass done in 8. Box done in 9. Rose done in', 'Clock done in 7. Zip done in 8. Cat done in 9. Snow done in 10. Ant done in', 'Rose done in 8. Ear done in 9. Rose done in 10. Rat done in 11. Orange done in', 'Road done in 1. Ring done in 2. Pen done in 3. Oil done in 4. Camera done in', 'House done in 2. Zip done in 3. Queen done in 4. Snow done in 5. Lake done in', 'Van done in 3. Tree done in 4. Wall done in 5. Rat done in 6. King done in', 'Ball done in 4. Hill done in 5. Clock done in 6. Ear done in 7. Van done in', 'Night done in 5. Ice done in 6. Apple done in 7. Tree done in 8. House done in', 'Clock done in 6. Orange done in 7. Queen done in 8. Desk done in 9. Arm done in', 'Map done in 7. Sun done in 8. Clock done in 9. Cat done in 10. Ball done in', 'Desk done in 8. Key done in 9. Star done in 10. Cow done in 11. Rose done in', 'Ring done in 1. Fan done in 2. Window done in 3. Tree done in 4. Chair done in', 'House done in 2. Nut done in 3. Queen done in 4. Zip done in 5. Rose done in', 'Window done in 3. Gate done in 4. Zip done in 5. Key done in 6. Snow done in', 'Corn done in 4. Ice done in 5. Eye done in 6. Light done in 7. Desk done in', 'Hill done in 5. Snake done in 6. Orange done in 7. Road done in 8. Flag done in', 'Queen done in 6. Window done in 7. Zip done in 8. Cow done in 9. Fire done in', 'Star done in 7. Hat done in 8. Chair done in 9. Car done in 10. Ring done in', 'Desk done in 8. Watch done in 9. Desk done in 10. Ax done in 11. Queen done in', 'Train done in 1. Snow done in 2. Cow done in 3. Ring done in 4. Queen done in', 'Window done in 2. Pen done in 3. Ax done in 4. Iron done in 5. Nut done in', 'Desk done in 3. Flag done in 4. Fan done in 5. Hat done in 6. Chair done in', 'King done in 4. Star done in 5. Cow done in 6. Wallet done in 7. Fan done in', 'Star done in 5. Watch done in 6. Car done in 7. Van done in 8. Queen done in']

import torch
import numpy as np
import re
from transformers import AutoTokenizer, BertForMaskedLM, DistilBertForMaskedLM

device = "cuda" if torch.cuda.is_available() else "cpu"

bert_model = BertForMaskedLM.from_pretrained("bert-base-uncased").to(device)
bert_tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
distilbert_model = DistilBertForMaskedLM.from_pretrained("distilbert-base-uncased").to(device)
distilbert_tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

bert_model.eval()
distilbert_model.eval()

def normalize_numerals(texts):
    normalized_texts = []
    for text in texts:
        matches = list(re.finditer(r'\b\d+\b', text))
        mapping = {match.group(): str(i + 1) for i, match in enumerate(matches)}
        normalized_text = re.sub(r'\b\d+\b', lambda m: mapping[m.group()], text)
        normalized_texts.append(normalized_text)
    return normalized_texts

texts = [t + " [MASK]" for t in normalize_numerals(texts)]

def compute_logit_diff(model, tokenizer, texts, target_token, distractor_token):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)
    with torch.no_grad():
        logits = model(**inputs).logits
    diffs = []
    for b, pos in zip(*mask_token_index):
        logits_slice = logits[b, pos]
        target_logit = logits_slice[tokenizer.convert_tokens_to_ids(target_token)]
        distractor_logit = logits_slice[tokenizer.convert_tokens_to_ids(distractor_token)]
        diffs.append((target_logit - distractor_logit).item())
    return np.mean(diffs)

target_token = '5'
distractor_token = '4'
bert_diff = compute_logit_diff(bert_model, bert_tokenizer, texts, target_token, distractor_token)
distilbert_diff = compute_logit_diff(distilbert_model, distilbert_tokenizer, texts, target_token, distractor_token)

print(f"BERT logit difference: {bert_diff:.4f}")
print(f"DistilBERT logit difference: {distilbert_diff:.4f}")

import torch
import numpy as np
import re
import matplotlib.pyplot as plt
from typing import List, Tuple, Dict
from torch.nn.functional import cosine_similarity
from transformers import (AutoTokenizer, BertForMaskedLM, DistilBertForMaskedLM)

device = "cuda" if torch.cuda.is_available() else "cpu"
teacher_str = "bert-base-uncased"
student_str = "distilbert-base-uncased"

teacher = BertForMaskedLM.from_pretrained(teacher_str).to(device)
student = DistilBertForMaskedLM.from_pretrained(student_str).to(device)
tokenizer_t = AutoTokenizer.from_pretrained(teacher_str)
tokenizer_s = AutoTokenizer.from_pretrained(student_str)

teacher.eval()
student.eval()

def normalize_numerals(texts):
    normalized_texts = []
    for text in texts:
        matches = list(re.finditer(r'\b\d+\b', text))
        mapping = {match.group(): str(i + 1) for i, match in enumerate(matches)}
        normalized_text = re.sub(r'\b\d+\b', lambda m: mapping[m.group()], text)
        normalized_texts.append(normalized_text)
    return normalized_texts

texts = [t + " [MASK]" for t in normalize_numerals(texts)]

def get_logits(model, tokenizer, texts):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)
    with torch.no_grad():
        outputs = model(**inputs, return_dict=True)
    return outputs.logits, inputs, mask_token_index

def compute_logit_diff(logits, input_ids, mask_token_index, tokenizer):
    diffs = []
    for b, pos in zip(*mask_token_index):
        logits_slice = logits[b, pos]
        correct_logit = logits_slice[tokenizer.convert_tokens_to_ids(target_token)]
        incorrect_logit = logits_slice[tokenizer.convert_tokens_to_ids(distractor_token)]
        diffs.append((correct_logit - incorrect_logit).item())
    return np.mean(diffs)

def get_ablation_hook(head_idx):
    def ablate_head(module, input, output):
        if isinstance(output, tuple):
            attn_output = output[0]
            attn_output[:, head_idx] = 0
            return (attn_output,) + output[1:]
        output[:, head_idx] = 0
        return output
    return ablate_head

def get_mlp_ablation_hook():
    return lambda module, input, output: torch.zeros_like(output)

def calculate_head_impacts(model, tokenizer, name='model'):
    is_distilbert = isinstance(model, DistilBertForMaskedLM)
    logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
    baseline_diff = compute_logit_diff(logits, inputs.input_ids, mask_token_index, tokenizer)
    num_layers = model.config.num_hidden_layers
    num_heads = model.config.num_attention_heads
    impacts = []
    for layer in range(num_layers):
        for head in range(num_heads):
            module = (model.distilbert.transformer.layer[layer].attention
                      if is_distilbert
                      else model.bert.encoder.layer[layer].attention.self)
            hook = module.register_forward_hook(get_ablation_hook(head))
            logits_ablated, _, _ = get_logits(model, tokenizer, texts)
            ablated_diff = compute_logit_diff(logits_ablated, inputs.input_ids, mask_token_index, tokenizer)
            hook.remove()
            impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
            impacts.append(((layer, head), abs(impact)))
    return impacts

def calculate_mlp_impacts(model, tokenizer, name='model'):
    is_distilbert = isinstance(model, DistilBertForMaskedLM)
    logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
    baseline_diff = compute_logit_diff(logits, inputs.input_ids, mask_token_index, tokenizer)
    impacts = []
    for layer in range(model.config.num_hidden_layers):
        module = (model.distilbert.transformer.layer[layer].ffn.lin1
                  if is_distilbert
                  else model.bert.encoder.layer[layer].intermediate.dense)
        hook = module.register_forward_hook(get_mlp_ablation_hook())
        try:
            logits_ablated, _, _ = get_logits(model, tokenizer, texts)
            ablated_diff = compute_logit_diff(logits_ablated, inputs.input_ids, mask_token_index, tokenizer)
            impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
            impacts.append((layer, abs(impact)))
        finally:
            hook.remove()
    return impacts

def get_head_vectors(model, tokenizer, top_heads: List[Tuple[int, int]]):
    is_distilbert = isinstance(model, DistilBertForMaskedLM)
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    with torch.no_grad():
        outputs = model(**inputs, output_attentions=True, return_dict=True)
    attentions = outputs.attentions
    vectors = {}
    for layer, head in top_heads:
        tensor = attentions[layer][:, head]
        vectors[(layer, head)] = tensor.mean(dim=0)
    return vectors


def get_mlp_vectors(model, tokenizer, top_layers: List[int]):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    with torch.no_grad():
        outputs = model(**inputs, output_hidden_states=True, return_dict=True)
    hidden_states = outputs.hidden_states
    vectors = {}
    for layer in top_layers:
        mlp_output = hidden_states[layer + 1]
        vectors[layer] = mlp_output.mean(dim=(0, 1))
    return vectors

import torch.nn.functional as F

def compute_best_matches_attn(src_dict: Dict, tgt_dict: Dict, threshold=0.0) -> Dict:
    matches = {}
    for s_key, s_mat in src_dict.items():
        best_sim, best_key = -1, None
        for t_key, t_mat in tgt_dict.items():
            sim = torch.mean(F.cosine_similarity(s_mat.unsqueeze(1), t_mat.unsqueeze(1), dim=2)).item()
            if sim > best_sim:
                best_sim, best_key = sim, t_key
        if best_sim >= threshold:
            matches[s_key] = (best_key, best_sim)
    return matches

import numpy as np
from scipy.linalg import svd
from sklearn.metrics.pairwise import cosine_similarity

def activation_eigenvector_similarity(acts1, acts2, k=3):
    acts1_flat = acts1.reshape(-1, acts1.shape[-1])
    acts2_flat = acts2.reshape(-1, acts2.shape[-1])

    cov1 = np.dot(acts1_flat.T, acts1_flat) / acts1_flat.shape[0]
    cov2 = np.dot(acts2_flat.T, acts2_flat) / acts2_flat.shape[0]

    U1, _, _ = svd(cov1)
    U2, _, _ = svd(cov2)
    U1_topk = U1[:, :k]
    U2_topk = U2[:, :k]

    sim_matrix = cosine_similarity(U1_topk.T, U2_topk.T)
    return np.mean(sim_matrix)

def compute_best_matches_mlp(src_dict: Dict, tgt_dict: Dict, threshold=0.0) -> Dict:
    matches = {}
    for s_key, s_vec in src_dict.items():
        best_sim, best_key = -1, None
        for t_key, t_vec in tgt_dict.items():
            sim = activation_eigenvector_similarity(s_vec.cpu().numpy(), t_vec.cpu().numpy())
            if sim > best_sim:
                best_sim, best_key = sim, t_key
        if best_sim >= threshold:
            matches[s_key] = (best_key, best_sim)
    return matches


def compute_best_matches_attn_biased_to_teacher(teacher_dict: Dict, student_dict: Dict) -> Dict:
    matches = {}
    for t_key, t_mat in teacher_dict.items():
        best_sim, best_key = -1, None
        for s_key, s_mat in student_dict.items():
            sim = torch.nn.functional.cosine_similarity(t_mat.flatten(), s_mat.flatten(), dim=0).item()
            if sim > best_sim:
                best_sim, best_key = sim, s_key
        matches[t_key] = (best_key, best_sim)
    return matches

def compute_best_matches_mlp_biased_to_teacher(teacher_dict: Dict, student_dict: Dict) -> Dict:
    matches = {}
    for t_key, t_vec in teacher_dict.items():
        best_sim, best_key = -1, None
        for s_key, s_vec in student_dict.items():
            sim = activation_eigenvector_similarity(t_vec.cpu().numpy(), s_vec.cpu().numpy())
            if sim > best_sim:
                best_sim, best_key = sim, s_key
        matches[t_key] = (best_key, best_sim)
    return matches

def compute_alignment_score(pairs: List[Tuple[float, float, float]]) -> float:
    return sum(S * (1 - abs(I_S - I_T)) for I_S, I_T, S in pairs) / len(pairs)

teacher_heads = calculate_head_impacts(teacher, tokenizer_t, name="Teacher")
student_heads = calculate_head_impacts(student, tokenizer_s, name="Student")
teacher_mlp = calculate_mlp_impacts(teacher, tokenizer_t, name="Teacher")
student_mlp = calculate_mlp_impacts(student, tokenizer_s, name="Student")

influence_teacher = {k: abs(v) for k, v in dict(teacher_heads + teacher_mlp).items()}
influence_student = {k: abs(v) for k, v in dict(student_heads + student_mlp).items()}

teacher_head_vecs = get_head_vectors(teacher, tokenizer_t, [x[0] for x in teacher_heads])
student_head_vecs = get_head_vectors(student, tokenizer_s, [x[0] for x in student_heads])

teacher_mlp_vecs = get_mlp_vectors(teacher, tokenizer_t, [x[0] for x in teacher_mlp])
student_mlp_vecs = get_mlp_vectors(student, tokenizer_s, [x[0] for x in student_mlp])

attn_matches = compute_best_matches_attn_biased_to_teacher(teacher_head_vecs, student_head_vecs)
mlp_matches = compute_best_matches_mlp_biased_to_teacher(teacher_mlp_vecs, student_mlp_vecs)

matches = {**attn_matches, **mlp_matches}
all_pairs = []
for teacher_comp, (student_comp, sim_score) in matches.items():
    I_T = influence_teacher.get(teacher_comp, 0)
    I_S = influence_student.get(student_comp, 0)
    all_pairs.append((I_S, I_T, sim_score))

scaled = [(I_S * len(all_pairs), I_T * len(all_pairs), S) for (I_S, I_T, S) in all_pairs]
sum_I_S = sum(x[0] for x in scaled)
sum_I_T = sum(x[1] for x in scaled)
normalized = [(I_S / sum_I_S, I_T / sum_I_T, S) for (I_S, I_T, S) in scaled]

alignment_score = compute_alignment_score(normalized)

print(f"Alignment score: {alignment_score:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# BERT logit difference: 1.1650
# DistilBERT logit difference: 0.4904
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# BertSdpaSelfAttention is used but `torch.nn.functional.scaled_dot_product_attention` does not support non-absolute `position_embedding_type` or `output_attentions=True` or `head_mask`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# DistilBertSdpaAttention is used but `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True` or `head_mask`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# Alignment score: 0.8214

# %% [markdown]
# ## IOI Task:

# %%
import torch
import numpy as np
from transformers import AutoTokenizer, BertForMaskedLM, DistilBertForMaskedLM
from typing import List, Tuple, Dict
from scipy.linalg import svd
from sklearn.metrics.pairwise import cosine_similarity as sklearn_cosine_similarity

device = "cuda" if torch.cuda.is_available() else "cpu"

bert_model = BertForMaskedLM.from_pretrained("bert-base-uncased").to(device)
distilbert_model = DistilBertForMaskedLM.from_pretrained("distilbert-base-uncased").to(device)
bert_tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
distilbert_tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
bert_model.eval()
distilbert_model.eval()

import re

raw_data = ['After Mark and Sara went to the office, Mark gave a kiss to Sara', 'Then, Brittany and Bryan had a lot of fun at the house. Brittany gave a snack to Bryan', 'Then, Emily and Kimberly went to the station. Kimberly gave a bone to Emily', 'Then, Christine and Stephanie went to the hospital. Christine gave a snack to Stephanie', 'When Emily and Christine got a necklace at the hospital, Christine decided to give it to Emily', 'Then, Megan and Robert were working at the station. Robert decided to give a basketball to Megan', 'Then, Jacob and Tyler were thinking about going to the house. Tyler wanted to give a necklace to Jacob', 'Then, Erin and Lauren had a lot of fun at the station. Lauren gave a basketball to Erin', 'After Brittany and Kevin went to the hospital, Brittany gave a ring to Kevin', 'Then, James and Nicole had a lot of fun at the house. James gave a snack to Nicole', 'Then, Adam and Bradley had a lot of fun at the station. Adam gave a snack to Bradley', 'When Jessica and Robert got a drink at the school, Robert decided to give it to Jessica', 'When Rachel and Megan got a snack at the office, Rachel decided to give it to Megan', 'Then, Danielle and Nathan had a lot of fun at the office. Danielle gave a necklace to Nathan', 'When Steven and Rebecca got a basketball at the hospital, Steven decided to give it to Rebecca', 'Then, Courtney and Nicole went to the garden. Nicole gave a bone to Courtney', 'After Heather and Alicia went to the hospital, Alicia gave a computer to Heather', 'Then, Nicole and Christina went to the office. Christina gave a bone to Nicole', 'Then, Shannon and Christopher were working at the restaurant. Shannon decided to give a computer to Christopher', 'Then, Joshua and Paul had a lot of fun at the restaurant. Paul gave a snack to Joshua', 'Then, Christopher and Scott went to the station. Scott gave a snack to Christopher', 'When Brittany and Brian got a snack at the hospital, Brian decided to give it to Brittany', 'Then, Daniel and Tiffany went to the garden. Tiffany gave a ring to Daniel', 'Then, Tyler and Sarah had a long argument, and afterwards Tyler said to Sarah', 'Then, Angela and Bradley went to the school. Bradley gave a drink to Angela', 'When Aaron and Kyle got a computer at the house, Kyle decided to give it to Aaron', 'Then, Amanda and Travis were thinking about going to the garden. Amanda wanted to give a basketball to Travis', 'Then, Heather and Kevin had a long argument, and afterwards Kevin said to Heather', 'After Stephanie and Paul went to the restaurant, Paul gave a ring to Stephanie', 'Then, Katie and Charles went to the station. Katie gave a computer to Charles', 'Then, Elizabeth and Timothy had a lot of fun at the hospital. Timothy gave a snack to Elizabeth', 'Then, Jesse and Elizabeth went to the school. Elizabeth gave a drink to Jesse', 'Then, Dustin and Eric went to the restaurant. Eric gave a computer to Dustin', 'Then, Justin and David were working at the restaurant. David decided to give a computer to Justin', 'Then, Tyler and Cody were thinking about going to the station. Tyler wanted to give a kiss to Cody', 'When Katie and Kyle got a computer at the house, Kyle decided to give it to Katie', 'Then, Erin and Dustin had a lot of fun at the garden. Erin gave a ring to Dustin', 'Then, Lauren and Alicia went to the hospital. Lauren gave a ring to Alicia', 'Then, Elizabeth and Alexander went to the store. Alexander gave a computer to Elizabeth', 'Then, Bradley and Jennifer were thinking about going to the restaurant. Bradley wanted to give a snack to Jennifer', 'Then, Aaron and Lindsey had a lot of fun at the restaurant. Aaron gave a drink to Lindsey', 'Then, Sean and Robert had a long argument, and afterwards Robert said to Sean', 'After Jose and Lauren went to the restaurant, Jose gave a necklace to Lauren', 'Then, Erin and Katie went to the house. Erin gave a ring to Katie', 'When Robert and Laura got a kiss at the office, Laura decided to give it to Robert', 'Then, Tiffany and Kelly were thinking about going to the station. Kelly wanted to give a drink to Tiffany', 'Then, Nicole and Samantha had a lot of fun at the station. Samantha gave a snack to Nicole', 'Then, Joshua and Anthony were thinking about going to the restaurant. Anthony wanted to give a computer to Joshua', 'When Lindsay and Sean got a basketball at the store, Sean decided to give it to Lindsay', 'When Rachel and William got a drink at the store, Rachel decided to give it to William', 'Then, Eric and Andrew went to the garden. Andrew gave a bone to Eric', 'When Vanessa and Christina got a drink at the hospital, Christina decided to give it to Vanessa', 'Then, Patrick and Stephen were working at the station. Stephen decided to give a bone to Patrick', 'Then, Gregory and Nicole went to the restaurant. Gregory gave a kiss to Nicole', 'Then, Benjamin and Samuel were working at the hospital. Benjamin decided to give a ring to Samuel', 'Then, Kyle and Courtney were working at the station. Kyle decided to give a bone to Courtney', 'When Sara and Patrick got a drink at the office, Patrick decided to give it to Sara', 'When Lauren and Nicole got a drink at the school, Nicole decided to give it to Lauren', 'After Jeremy and Jennifer went to the station, Jennifer gave a drink to Jeremy', 'Then, Lindsey and Kristen went to the station. Lindsey gave a ring to Kristen', 'Then, Andrea and Jamie had a long argument, and afterwards Andrea said to Jamie', 'Then, Nathan and Rebecca went to the restaurant. Rebecca gave a drink to Nathan', 'Then, Lindsey and Sarah were working at the station. Sarah decided to give a computer to Lindsey', 'After Katie and Travis went to the garden, Katie gave a necklace to Travis', 'Then, Alexander and Sara were working at the office. Sara decided to give a snack to Alexander', 'Then, Dustin and Ashley were working at the garden. Ashley decided to give a basketball to Dustin', 'Then, Jesse and Timothy had a long argument, and afterwards Timothy said to Jesse', 'Then, Bradley and Kenneth went to the garden. Kenneth gave a snack to Bradley', 'Then, Kyle and Katie had a long argument, and afterwards Kyle said to Katie', 'Then, Amanda and Christina were thinking about going to the office. Christina wanted to give a drink to Amanda', 'Then, Nathan and Megan had a long argument, and afterwards Nathan said to Megan', 'Then, Mary and James had a long argument, and afterwards Mary said to James', 'Then, Elizabeth and Justin were thinking about going to the hospital. Elizabeth wanted to give a snack to Justin', 'Then, Christopher and Jose were working at the hospital. Christopher decided to give a bone to Jose', 'Then, Aaron and Danielle went to the hospital. Danielle gave a drink to Aaron', 'When Rebecca and Melissa got a drink at the school, Rebecca decided to give it to Melissa', 'Then, Patrick and Joseph were working at the house. Joseph decided to give a necklace to Patrick', 'Then, Kristen and Jessica were thinking about going to the hospital. Kristen wanted to give a ring to Jessica', 'Then, Cody and Jesse were thinking about going to the station. Cody wanted to give a computer to Jesse', 'Then, Elizabeth and Erica were thinking about going to the school. Erica wanted to give a basketball to Elizabeth', 'Then, Alexander and Melissa were thinking about going to the restaurant. Alexander wanted to give a kiss to Melissa', 'Then, Bryan and Jennifer had a long argument, and afterwards Jennifer said to Bryan', 'Then, Christine and Kimberly were thinking about going to the garden. Christine wanted to give a computer to Kimberly', 'After Benjamin and Cody went to the school, Benjamin gave a bone to Cody', 'Then, Dustin and Kimberly were thinking about going to the hospital. Kimberly wanted to give a bone to Dustin', 'Then, Christina and Patrick were working at the office. Christina decided to give a kiss to Patrick', 'When David and Justin got a drink at the school, Justin decided to give it to David', 'Then, Angela and Kimberly were working at the house. Kimberly decided to give a ring to Angela', 'Then, Ryan and Sara were working at the office. Ryan decided to give a computer to Sara', 'Then, Kenneth and Amy were thinking about going to the garden. Kenneth wanted to give a basketball to Amy', 'When Matthew and Travis got a basketball at the office, Travis decided to give it to Matthew', 'Then, Daniel and Kenneth had a long argument, and afterwards Kenneth said to Daniel', 'Then, Jason and Jennifer went to the hospital. Jennifer gave a snack to Jason', 'Then, John and Adam went to the restaurant. Adam gave a drink to John', 'When Jeffrey and Jose got a bone at the house, Jose decided to give it to Jeffrey', 'Then, John and Lindsey went to the house. John gave a computer to Lindsey', 'Then, Katie and Jeffrey had a lot of fun at the station. Jeffrey gave a snack to Katie', 'After Kimberly and John went to the office, John gave a necklace to Kimberly', 'Then, Michelle and Thomas had a lot of fun at the garden. Thomas gave a snack to Michelle', 'Then, Kristen and Heather went to the store. Heather gave a ring to Kristen']


texts = []
targets = []
distractors = []

pattern = re.compile(
    r"(?i)(?:After|Then|When)?[^.,;]*?\b(\w+)\b and \b(\w+)\b.*?"
    r"\b(\1|\2)\b.*?"
    r"(?:gave|wanted to give|decided to give|said to).*?\bto (\w+)\b"
)

for sentence in raw_data:
    match = pattern.search(sentence)
    if match:
        person1, person2, giver, recipient = match.groups()

        recipient_pattern = re.compile(rf"\bto {re.escape(recipient)}\b", re.IGNORECASE)
        masked_sentence = recipient_pattern.sub("to [MASK]", sentence, count=1)

        texts.append(masked_sentence.strip().rstrip('.') + '.')
        targets.append(recipient.lower())
        distractors.append((person1 if recipient.lower() != person1.lower() else person2).lower())

def compute_logit_diff_ioi(model, tokenizer, texts, targets, distractors):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)
    with torch.no_grad():
        logits = model(**inputs).logits
    diffs = []
    for i, (b, pos) in enumerate(zip(*mask_token_index)):
        tgt_id = tokenizer.convert_tokens_to_ids(targets[i])
        dst_id = tokenizer.convert_tokens_to_ids(distractors[i])
        logits_slice = logits[b, pos]
        diffs.append((logits_slice[tgt_id] - logits_slice[dst_id]).item())
    return np.mean(diffs)

bert_diff = compute_logit_diff_ioi(bert_model, bert_tokenizer, texts, targets, distractors)
distilbert_diff = compute_logit_diff_ioi(distilbert_model, distilbert_tokenizer, texts, targets, distractors)

print(f"BERT logit difference: {bert_diff:.4f}")
print(f"DistilBERT logit difference: {distilbert_diff:.4f}")

def get_logits(model, tokenizer, texts):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)
    with torch.no_grad():
        outputs = model(**inputs, return_dict=True)
    return outputs.logits, inputs, mask_token_index

def compute_logit_diff_ioi_logits(logits, input_ids, mask_token_index, tokenizer, targets, distractors):
    diffs = []
    for i, (b, pos) in enumerate(zip(*mask_token_index)):
        tgt_id = tokenizer.convert_tokens_to_ids(targets[i])
        dst_id = tokenizer.convert_tokens_to_ids(distractors[i])
        logits_slice = logits[b, pos]
        diffs.append((logits_slice[tgt_id] - logits_slice[dst_id]).item())
    return np.mean(diffs)

def get_ablation_hook(head_idx):
    def ablate_head(module, input, output):
        if isinstance(output, tuple):
            attn_output = output[0]
            attn_output[:, head_idx] = 0
            return (attn_output,) + output[1:]
        output[:, head_idx] = 0
        return output
    return ablate_head

def get_mlp_ablation_hook():
    return lambda module, input, output: torch.zeros_like(output)

def calculate_head_impacts(model, tokenizer, texts, targets, distractors):
    is_distilbert = isinstance(model, DistilBertForMaskedLM)
    logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
    baseline_diff = compute_logit_diff_ioi_logits(logits, inputs.input_ids, mask_token_index, tokenizer, targets, distractors)
    num_layers = model.config.num_hidden_layers
    num_heads = model.config.num_attention_heads
    impacts = []
    for layer in range(num_layers):
        for head in range(num_heads):
            module = model.distilbert.transformer.layer[layer].attention if is_distilbert else model.bert.encoder.layer[layer].attention.self
            hook = module.register_forward_hook(get_ablation_hook(head))
            logits_ablated, _, _ = get_logits(model, tokenizer, texts)
            ablated_diff = compute_logit_diff_ioi_logits(logits_ablated, inputs.input_ids, mask_token_index, tokenizer, targets, distractors)
            hook.remove()
            impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
            impacts.append(((layer, head), abs(impact)))
    return impacts

def calculate_mlp_impacts(model, tokenizer, texts, targets, distractors):
    is_distilbert = isinstance(model, DistilBertForMaskedLM)
    logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
    baseline_diff = compute_logit_diff_ioi_logits(logits, inputs.input_ids, mask_token_index, tokenizer, targets, distractors)
    impacts = []
    for layer in range(model.config.num_hidden_layers):
        module = model.distilbert.transformer.layer[layer].ffn.lin1 if is_distilbert else model.bert.encoder.layer[layer].intermediate.dense
        hook = module.register_forward_hook(get_mlp_ablation_hook())
        try:
            logits_ablated, _, _ = get_logits(model, tokenizer, texts)
            ablated_diff = compute_logit_diff_ioi_logits(logits_ablated, inputs.input_ids, mask_token_index, tokenizer, targets, distractors)
            impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
            impacts.append((layer, abs(impact)))
        finally:
            hook.remove()
    return impacts

def get_head_vectors(model, tokenizer, texts, top_heads: List[Tuple[int, int]]):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    with torch.no_grad():
        outputs = model(**inputs, output_attentions=True, return_dict=True)
    attentions = outputs.attentions
    vectors = {}
    for layer, head in top_heads:
        vectors[(layer, head)] = attentions[layer][:, head].mean(dim=0)
    return vectors

def get_mlp_vectors(model, tokenizer, texts, top_layers: List[int]):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    with torch.no_grad():
        outputs = model(**inputs, output_hidden_states=True, return_dict=True)
    hidden_states = outputs.hidden_states
    vectors = {}
    for layer in top_layers:
        vectors[layer] = hidden_states[layer + 1].mean(dim=(0, 1))
    return vectors

def activation_eigenvector_similarity(acts1, acts2, k=3):
    acts1_flat = acts1.reshape(-1, acts1.shape[-1])
    acts2_flat = acts2.reshape(-1, acts2.shape[-1])
    cov1 = np.dot(acts1_flat.T, acts1_flat) / acts1_flat.shape[0]
    cov2 = np.dot(acts2_flat.T, acts2_flat) / acts2_flat.shape[0]
    U1, _, _ = svd(cov1)
    U2, _, _ = svd(cov2)
    sim_matrix = sklearn_cosine_similarity(U1[:, :k].T, U2[:, :k].T)
    return np.mean(sim_matrix)

def compute_best_matches_attn(src_dict: Dict, tgt_dict: Dict) -> Dict:
    matches = {}
    for s_key, s_mat in src_dict.items():
        best_sim, best_key = -1, None
        for t_key, t_mat in tgt_dict.items():
            sim = torch.nn.functional.cosine_similarity(s_mat.flatten(), t_mat.flatten(), dim=0).item()
            if sim > best_sim:
                best_sim, best_key = sim, t_key
        matches[s_key] = (best_key, best_sim)
    return matches

def compute_best_matches_mlp(src_dict: Dict, tgt_dict: Dict) -> Dict:
    matches = {}
    for s_key, s_vec in src_dict.items():
        best_sim, best_key = -1, None
        for t_key, t_vec in tgt_dict.items():
            sim = activation_eigenvector_similarity(s_vec.cpu().numpy(), t_vec.cpu().numpy())
            if sim > best_sim:
                best_sim, best_key = sim, t_key
        matches[s_key] = (best_key, best_sim)
    return matches


def compute_best_matches_attn_biased_to_teacher(teacher_dict: Dict, student_dict: Dict) -> Dict:
    matches = {}
    for t_key, t_mat in teacher_dict.items():
        best_sim, best_key = -1, None
        for s_key, s_mat in student_dict.items():
            sim = torch.nn.functional.cosine_similarity(t_mat.flatten(), s_mat.flatten(), dim=0).item()
            if sim > best_sim:
                best_sim, best_key = sim, s_key
        matches[t_key] = (best_key, best_sim)
    return matches

def compute_best_matches_mlp_biased_to_teacher(teacher_dict: Dict, student_dict: Dict) -> Dict:
    matches = {}
    for t_key, t_vec in teacher_dict.items():
        best_sim, best_key = -1, None
        for s_key, s_vec in student_dict.items():
            sim = activation_eigenvector_similarity(t_vec.cpu().numpy(), s_vec.cpu().numpy())
            if sim > best_sim:
                best_sim, best_key = sim, s_key
        matches[t_key] = (best_key, best_sim)
    return matches


def compute_alignment_score(pairs: List[Tuple[float, float, float]]) -> float:
    return sum(S * (1 - abs(I_S - I_T)) for I_S, I_T, S in pairs) / len(pairs)

bert_diff = compute_logit_diff_ioi(bert_model, bert_tokenizer, texts, targets, distractors)
distilbert_diff = compute_logit_diff_ioi(distilbert_model, distilbert_tokenizer, texts, targets, distractors)

teacher_heads = calculate_head_impacts(bert_model, bert_tokenizer, texts, targets, distractors)
student_heads = calculate_head_impacts(distilbert_model, distilbert_tokenizer, texts, targets, distractors)
teacher_mlp = calculate_mlp_impacts(bert_model, bert_tokenizer, texts, targets, distractors)
student_mlp = calculate_mlp_impacts(distilbert_model, distilbert_tokenizer, texts, targets, distractors)

influence_teacher = {k: v for k, v in dict(teacher_heads + teacher_mlp).items()}
influence_student = {k: v for k, v in dict(student_heads + student_mlp).items()}

student_head_vecs = get_head_vectors(distilbert_model, distilbert_tokenizer, texts, [x[0] for x in student_heads])
teacher_head_vecs = get_head_vectors(bert_model, bert_tokenizer, texts, [x[0] for x in teacher_heads])
student_mlp_vecs = get_mlp_vectors(distilbert_model, distilbert_tokenizer, texts, [x[0] for x in student_mlp])
teacher_mlp_vecs = get_mlp_vectors(bert_model, bert_tokenizer, texts, [x[0] for x in teacher_mlp])

attn_matches = compute_best_matches_attn_biased_to_teacher(teacher_head_vecs, student_head_vecs)
mlp_matches = compute_best_matches_mlp_biased_to_teacher(teacher_mlp_vecs, student_mlp_vecs)

matches = {**attn_matches, **mlp_matches}
all_pairs = []
for teacher_comp, (student_comp, sim_score) in matches.items():
    I_T = influence_teacher.get(teacher_comp, 0)
    I_S = influence_student.get(student_comp, 0)
    all_pairs.append((I_S, I_T, sim_score))

scaled = [(I_S * len(all_pairs), I_T * len(all_pairs), S) for (I_S, I_T, S) in all_pairs]
sum_I_S = sum(x[0] for x in scaled)
sum_I_T = sum(x[1] for x in scaled)
normalized = [(I_S / sum_I_S, I_T / sum_I_T, S) for (I_S, I_T, S) in scaled]

alignment_score = compute_alignment_score(normalized)

print(f"Alignment score: {alignment_score:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# BERT logit difference: 5.2719
# DistilBERT logit difference: 3.6959
# DistilBertSdpaAttention is used but `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True` or `head_mask`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# BertSdpaSelfAttention is used but `torch.nn.functional.scaled_dot_product_attention` does not support non-absolute `position_embedding_type` or `output_attentions=True` or `head_mask`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# Alignment score: 0.8541

# %% [markdown]
# ## GPT2-small / DistilBERT (numeral sequence completion):

# %%
from typing import List, Tuple, Dict
import torch
import numpy as np
import re
import torch.nn.functional as F
from transformers import AutoTokenizer, GPT2LMHeadModel, DistilBertForMaskedLM

device = "cuda" if torch.cuda.is_available() else "cpu"
teacher_str = "gpt2"
student_str = "distilbert-base-uncased"

teacher = GPT2LMHeadModel.from_pretrained(teacher_str).to(device)
tokenizer_t = AutoTokenizer.from_pretrained(teacher_str)
tokenizer_t.pad_token = tokenizer_t.eos_token
tokenizer_t.padding_side = "left"

student = DistilBertForMaskedLM.from_pretrained(student_str).to(device)
tokenizer_s = AutoTokenizer.from_pretrained(student_str)

teacher.eval()
student.eval()

texts = ['Van done in 1. Hat done in 2. Ring done in 3. Desk done in 4. Sun done in', 'Ice done in 2. Snow done in 3. Watch done in 4. Sun done in 5. Table done in', 'Ring done in 3. Moon done in 4. Queen done in 5. Book done in 6. Rose done in', 'Queen done in 4. Oil done in 5. Rose done in 6. Desk done in 7. Car done in', 'Light done in 5. Arm done in 6. Road done in 7. Book done in 8. Ice done in', 'Ball done in 6. Cow done in 7. Book done in 8. Rose done in 9. Key done in', 'Road done in 7. Key done in 8. Ocean done in 9. Key done in 10. Queen done in', 'House done in 8. Rose done in 9. Key done in 10. Hat done in 11. Van done in', 'Ring done in 1. Car done in 2. Apple done in 3. Pear done in 4. Moon done in', 'Star done in 2. Sun done in 3. Road done in 4. Queen done in 5. Box done in', 'Hill done in 3. Ant done in 4. Apple done in 5. House done in 6. Hat done in', 'Chair done in 4. Van done in 5. Orange done in 6. Queen done in 7. Zip done in', 'Gate done in 5. Desk done in 6. Wolf done in 7. Rain done in 8. Flag done in', 'Queen done in 6. House done in 7. Light done in 8. Cat done in 9. Moon done in', 'Zip done in 7. Car done in 8. Ring done in 9. Hand done in 10. Fish done in', 'Snake done in 8. Queen done in 9. Window done in 10. Ear done in 11. Orange done in', 'Ice done in 1. Sand done in 2. Desk done in 3. Van done in 4. Hat done in', 'Camera done in 2. Watch done in 3. Dog done in 4. Book done in 5. Desk done in', 'Rain done in 3. Dog done in 4. Rat done in 5. Nut done in 6. Ocean done in', 'Night done in 4. Hat done in 5. Wall done in 6. Book done in 7. Tree done in', 'Gate done in 5. Chair done in 6. Ring done in 7. Hill done in 8. Car done in', 'Ax done in 6. Fan done in 7. Cat done in 8. Ring done in 9. Ring done in', 'Rose done in 7. Night done in 8. Van done in 9. Orange done in 10. Apple done in', 'Orange done in 8. Ear done in 9. Book done in 10. Ring done in 11. Bird done in', 'Ball done in 1. Wind done in 2. Wallet done in 3. Tree done in 4. Sand done in', 'Table done in 2. Jam done in 3. Apple done in 4. Pear done in 5. Ice done in', 'Gate done in 3. Train done in 4. Hat done in 5. Fan done in 6. Key done in', 'Window done in 4. Desk done in 5. Year done in 6. Van done in 7. Camera done in', 'Car done in 5. Watch done in 6. Oil done in 7. Queen done in 8. Fan done in', 'Mouse done in 6. Rose done in 7. Table done in 8. Clock done in 9. Queen done in', 'Year done in 7. Wheel done in 8. Wolf done in 9. Arm done in 10. Ax done in', 'Key done in 8. Ring done in 9. Night done in 10. Fan done in 11. Clock done in', 'Glass done in 1. Key done in 2. Nut done in 3. Rat done in 4. Van done in', 'Star done in 2. Pear done in 3. Bug done in 4. Bird done in 5. Ring done in', 'Road done in 3. Wind done in 4. Rat done in 5. Wolf done in 6. Map done in', 'Car done in 4. Ant done in 5. Rose done in 6. Van done in 7. Wolf done in', 'Zip done in 5. Hat done in 6. Wind done in 7. Rain done in 8. Car done in', 'Ring done in 6. Light done in 7. Jar done in 8. Dog done in 9. Fish done in', 'Bug done in 7. Key done in 8. Gate done in 9. Orange done in 10. Ring done in', 'Flag done in 8. Fire done in 9. Pear done in 10. Ax done in 11. Ear done in', 'Ring done in 1. Flag done in 2. Queen done in 3. Map done in 4. Camera done in', 'Desk done in 2. Fire done in 3. Desk done in 4. Road done in 5. Watch done in', 'Queen done in 3. House done in 4. Flag done in 5. Tree done in 6. Ring done in', 'Desk done in 4. Window done in 5. Fish done in 6. Jar done in 7. Hat done in', 'Snake done in 5. Key done in 6. Glass done in 7. Van done in 8. House done in', 'Camera done in 6. Year done in 7. Rose done in 8. Map done in 9. Fire done in', 'Rose done in 7. Snake done in 8. Corn done in 9. Desk done in 10. Zip done in', 'Table done in 8. Key done in 9. Eye done in 10. Van done in 11. Key done in', 'Star done in 1. Hat done in 2. Star done in 3. Eye done in 4. Gold done in', 'Gate done in 2. Queen done in 3. Camera done in 4. Zip done in 5. Ocean done in', 'Fan done in 3. Corn done in 4. Apple done in 5. Van done in 6. Cat done in', 'Key done in 4. Gold done in 5. Star done in 6. Queen done in 7. Arm done in', 'Van done in 5. Snake done in 6. Car done in 7. Star done in 8. Watch done in', 'Jar done in 6. Flag done in 7. Window done in 8. Sun done in 9. Van done in', 'Wolf done in 7. Watch done in 8. Ring done in 9. Desk done in 10. Car done in', 'Cow done in 8. Tree done in 9. Book done in 10. Wall done in 11. Flag done in', 'Van done in 1. Wall done in 2. Ring done in 3. Car done in 4. Key done in', 'Jar done in 2. Wallet done in 3. Fish done in 4. Watch done in 5. Orange done in', 'Watch done in 3. Orange done in 4. Table done in 5. Corn done in 6. Van done in', 'Lake done in 4. Star done in 5. Fan done in 6. Fan done in 7. Night done in', 'Fan done in 5. Ball done in 6. Desk done in 7. Jam done in 8. Tree done in', 'Key done in 6. Jar done in 7. Night done in 8. Fish done in 9. Fan done in', 'Ice done in 7. Rose done in 8. Wall done in 9. Road done in 10. Window done in', 'Tree done in 8. Hill done in 9. Wall done in 10. Queen done in 11. Desk done in', 'Gold done in 1. King done in 2. Queen done in 3. Desk done in 4. Night done in', 'Van done in 2. Sand done in 3. Tree done in 4. Car done in 5. Cow done in', 'Pear done in 3. Eye done in 4. Lake done in 5. Fan done in 6. Light done in', 'Jam done in 4. Road done in 5. Corn done in 6. Ice done in 7. Pen done in', 'Iron done in 5. Ring done in 6. Star done in 7. Van done in 8. Star done in', 'Bird done in 6. Wheel done in 7. Cat done in 8. Desk done in 9. Desk done in', 'Fish done in 7. Gold done in 8. King done in 9. Ax done in 10. Jam done in', 'Desk done in 8. House done in 9. Cow done in 10. Hill done in 11. Gate done in', 'Nut done in 1. Light done in 2. Sand done in 3. Wall done in 4. Key done in', 'Tree done in 2. Fan done in 3. Car done in 4. Desk done in 5. Ring done in', 'Orange done in 3. Ocean done in 4. Sun done in 5. Bug done in 6. Queen done in', 'Orange done in 4. House done in 5. Watch done in 6. Corn done in 7. Ring done in', 'Wind done in 5. Orange done in 6. Rose done in 7. Zip done in 8. Queen done in', 'Iron done in 6. Cat done in 7. Glass done in 8. Box done in 9. Rose done in', 'Clock done in 7. Zip done in 8. Cat done in 9. Snow done in 10. Ant done in', 'Rose done in 8. Ear done in 9. Rose done in 10. Rat done in 11. Orange done in', 'Road done in 1. Ring done in 2. Pen done in 3. Oil done in 4. Camera done in', 'House done in 2. Zip done in 3. Queen done in 4. Snow done in 5. Lake done in', 'Van done in 3. Tree done in 4. Wall done in 5. Rat done in 6. King done in', 'Ball done in 4. Hill done in 5. Clock done in 6. Ear done in 7. Van done in', 'Night done in 5. Ice done in 6. Apple done in 7. Tree done in 8. House done in', 'Clock done in 6. Orange done in 7. Queen done in 8. Desk done in 9. Arm done in', 'Map done in 7. Sun done in 8. Clock done in 9. Cat done in 10. Ball done in', 'Desk done in 8. Key done in 9. Star done in 10. Cow done in 11. Rose done in', 'Ring done in 1. Fan done in 2. Window done in 3. Tree done in 4. Chair done in', 'House done in 2. Nut done in 3. Queen done in 4. Zip done in 5. Rose done in', 'Window done in 3. Gate done in 4. Zip done in 5. Key done in 6. Snow done in', 'Corn done in 4. Ice done in 5. Eye done in 6. Light done in 7. Desk done in', 'Hill done in 5. Snake done in 6. Orange done in 7. Road done in 8. Flag done in', 'Queen done in 6. Window done in 7. Zip done in 8. Cow done in 9. Fire done in', 'Star done in 7. Hat done in 8. Chair done in 9. Car done in 10. Ring done in', 'Desk done in 8. Watch done in 9. Desk done in 10. Ax done in 11. Queen done in', 'Train done in 1. Snow done in 2. Cow done in 3. Ring done in 4. Queen done in', 'Window done in 2. Pen done in 3. Ax done in 4. Iron done in 5. Nut done in', 'Desk done in 3. Flag done in 4. Fan done in 5. Hat done in 6. Chair done in', 'King done in 4. Star done in 5. Cow done in 6. Wallet done in 7. Fan done in', 'Star done in 5. Watch done in 6. Car done in 7. Van done in 8. Queen done in']

def normalize_numerals(texts):
    normalized = []
    for text in texts:
        matches = list(re.finditer(r'\b\d+\b', text))
        mapping = {match.group(): str(i + 1) for i, match in enumerate(matches)}
        norm_text = re.sub(r'\b\d+\b', lambda m: mapping[m.group()], text)
        normalized.append(norm_text)
    return normalized

texts = normalize_numerals(texts)
target_token = '5'
distractor_token = '4'
texts_t = [t + " " + target_token for t in texts]
texts_s = [t + " [MASK]" for t in texts]

def get_logits_gpt2(model, tokenizer, texts):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    with torch.no_grad():
        outputs = model(**inputs, output_attentions=True, output_hidden_states=True, return_dict=True)
    last_token_indices = (inputs.input_ids != tokenizer.pad_token_id).sum(dim=1) - 1
    return outputs.logits, inputs, last_token_indices, outputs.attentions, outputs.hidden_states

def get_logits_mlm(model, tokenizer, texts):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)
    with torch.no_grad():
        outputs = model(**inputs, output_attentions=True, output_hidden_states=True, return_dict=True)
    return outputs.logits, inputs, mask_token_index, outputs.attentions, outputs.hidden_states


def compute_logit_diff_gpt2(model, tokenizer, texts, target_token, distractor_token):
    diffs = []
    target_id = tokenizer.encode(" " + target_token, add_special_tokens=False)[0]
    distractor_id = tokenizer.encode(" " + distractor_token, add_special_tokens=False)[0]

    for text in texts:
        inputs = tokenizer(text, return_tensors="pt").to(device)
        input_ids = inputs.input_ids
        with torch.no_grad():
            logits = model(**inputs).logits
        pred_pos = input_ids.shape[1] - 1

        logits_slice = logits[0, pred_pos]
        diff = logits_slice[target_id] - logits_slice[distractor_id]
        diffs.append(diff.item())

    return np.mean(diffs)



def compute_logit_diff_mlm(logits, input_ids, mask_token_index, tokenizer):
    diffs = []
    for b, pos in zip(*mask_token_index):
        logits_slice = logits[b, pos]
        diffs.append((logits_slice[tokenizer.convert_tokens_to_ids(target_token)] -
                      logits_slice[tokenizer.convert_tokens_to_ids(distractor_token)]).item())
    return np.mean(diffs)

def get_head_vectors_gpt2(model, tokenizer, top_heads):
    _, inputs, _, attentions, _ = get_logits_gpt2(model, tokenizer, texts_t)
    vectors = {}
    for layer, head in top_heads:
        attn_map = attentions[layer][:, head]
        vectors[(layer, head)] = attn_map.mean(dim=0)
    return vectors

def get_head_vectors_distilbert(model, tokenizer, top_heads):
    _, inputs, _, attentions, _ = get_logits_mlm(model, tokenizer, texts_s)
    vectors = {}
    for layer, head in top_heads:
        attn_map = attentions[layer][:, head]
        vectors[(layer, head)] = attn_map.mean(dim=0)
    return vectors

def get_mlp_vectors_gpt2(model, tokenizer, top_layers):
    _, inputs, _, _, hidden_states = get_logits_gpt2(model, tokenizer, texts_t)
    vectors = {}
    for layer in top_layers:
        mlp_output = hidden_states[layer + 1]
        vectors[layer] = mlp_output.mean(dim=(0, 1))
    return vectors

def get_mlp_vectors_distilbert(model, tokenizer, top_layers):
    _, inputs, _, _, hidden_states = get_logits_mlm(model, tokenizer, texts_s)
    vectors = {}
    for layer in top_layers:
        mlp_output = hidden_states[layer + 1]
        vectors[layer] = mlp_output.mean(dim=(0, 1))
    return vectors

def activation_eigenvector_similarity(acts1, acts2, k=3):
    acts1_flat = acts1.reshape(-1, acts1.shape[-1])
    acts2_flat = acts2.reshape(-1, acts2.shape[-1])
    cov1 = np.dot(acts1_flat.T, acts1_flat) / acts1_flat.shape[0]
    cov2 = np.dot(acts2_flat.T, acts2_flat) / acts2_flat.shape[0]
    U1, _, _ = np.linalg.svd(cov1)
    U2, _, _ = np.linalg.svd(cov2)
    return np.mean(np.dot(U1[:, :k].T, U2[:, :k]))

def compute_best_matches_attn(teacher_dict, student_dict):
    matches = {}
    for t_key, t_mat in teacher_dict.items():
        best_sim, best_key = -1, None
        for s_key, s_mat in student_dict.items():
            min_shape = min(t_mat.shape[0], s_mat.shape[0])
            t_vec = t_mat[:min_shape, :min_shape].flatten()
            s_vec = s_mat[:min_shape, :min_shape].flatten()
            sim = F.cosine_similarity(t_vec, s_vec, dim=0).item()
            if sim > best_sim:
                best_sim, best_key = sim, s_key
        matches[t_key] = (best_key, best_sim)
    return matches

def compute_best_matches_mlp(teacher_dict, student_dict):
    matches = {}
    for t_key, t_vec in teacher_dict.items():
        best_sim, best_key = -1, None
        for s_key, s_vec in student_dict.items():
            sim = activation_eigenvector_similarity(t_vec.cpu().numpy(), s_vec.cpu().numpy())
            if sim > best_sim:
                best_sim, best_key = sim, s_key
        matches[t_key] = (best_key, best_sim)
    return matches

def compute_alignment_score(pairs: List[Tuple[float, float, float]]) -> float:
    return sum(S * (1 - abs(I_S - I_T)) for I_S, I_T, S in pairs) / len(pairs)

def get_ablation_hook_gpt2(head_idx):
    def ablate_head(module, input, output):
        if isinstance(output, tuple):
            attn_output, *rest = output
            attn_output[:, :, head_idx] = 0
            return (attn_output,) + tuple(rest)
        else:
            output[:, :, head_idx] = 0
            return output
    return ablate_head


def get_ablation_hook_distilbert(head_idx):
    def ablate_head(module, input, output):
        if isinstance(output, tuple):
            attn_output, *rest = output
            attn_output[:, head_idx] = 0
            return (attn_output,) + tuple(rest)
        else:
            output[:, head_idx] = 0
            return output
    return ablate_head


def get_mlp_ablation_hook():
    return lambda module, input, output: torch.zeros_like(output)

def calculate_head_impacts_gpt2(model, tokenizer):
    baseline_diff = compute_logit_diff_gpt2(model, tokenizer, texts, target_token, distractor_token)
    num_layers = model.config.n_layer
    num_heads = model.config.n_head
    impacts = []
    for layer in range(num_layers):
        module = model.transformer.h[layer].attn
        for head in range(num_heads):
            hook = module.register_forward_hook(get_ablation_hook_gpt2(head))
            try:
                ablated_diff = compute_logit_diff_gpt2(model, tokenizer, texts, target_token, distractor_token)
                impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
                impacts.append(((layer, head), abs(impact)))
            finally:
                hook.remove()
    return impacts


def calculate_mlp_impacts_gpt2(model, tokenizer):
    baseline_diff = compute_logit_diff_gpt2(model, tokenizer, texts, target_token, distractor_token)

    impacts = []
    for layer in range(model.config.n_layer):
        module = model.transformer.h[layer].mlp.c_fc
        hook = module.register_forward_hook(get_mlp_ablation_hook())
        try:
            ablated_diff = compute_logit_diff_gpt2(model, tokenizer, texts, target_token, distractor_token)
            impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
            impacts.append((layer, abs(impact)))
        finally:
            hook.remove()
    return impacts


def calculate_head_impacts_distilbert(model, tokenizer):
    logits, inputs, mask_token_index, _, _ = get_logits_mlm(model, tokenizer, texts_s)
    baseline_diff = compute_logit_diff_mlm(logits, inputs.input_ids, mask_token_index, tokenizer)
    num_layers = model.config.num_hidden_layers
    num_heads = model.config.num_attention_heads
    impacts = []
    for layer in range(num_layers):
        module = model.distilbert.transformer.layer[layer].attention
        for head in range(num_heads):
            hook = module.register_forward_hook(get_ablation_hook_distilbert(head))
            try:
                logits_ablated, _, mask_token_index, _, _ = get_logits_mlm(model, tokenizer, texts_s)
                ablated_diff = compute_logit_diff_mlm(logits_ablated, inputs.input_ids, mask_token_index, tokenizer)
                impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
                impacts.append(((layer, head), abs(impact)))
            finally:
                hook.remove()
    return impacts

def calculate_mlp_impacts_distilbert(model, tokenizer):
    logits, inputs, mask_token_index, _, _ = get_logits_mlm(model, tokenizer, texts_s)
    baseline_diff = compute_logit_diff_mlm(logits, inputs.input_ids, mask_token_index, tokenizer)
    impacts = []
    for layer in range(model.config.num_hidden_layers):
        module = model.distilbert.transformer.layer[layer].ffn.lin1
        hook = module.register_forward_hook(get_mlp_ablation_hook())
        try:
            logits_ablated, _, mask_token_index, _, _ = get_logits_mlm(model, tokenizer, texts_s)
            ablated_diff = compute_logit_diff_mlm(logits_ablated, inputs.input_ids, mask_token_index, tokenizer)
            impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
            impacts.append((layer, abs(impact)))
        finally:
            hook.remove()
    return impacts

teacher_heads = calculate_head_impacts_gpt2(teacher, tokenizer_t)
teacher_mlp = calculate_mlp_impacts_gpt2(teacher, tokenizer_t)
student_heads = calculate_head_impacts_distilbert(student, tokenizer_s)
student_mlp = calculate_mlp_impacts_distilbert(student, tokenizer_s)

influence_teacher = {k: abs(v) for k, v in dict(teacher_heads + teacher_mlp).items()}
influence_student = {k: abs(v) for k, v in dict(student_heads + student_mlp).items()}

teacher_head_vecs = get_head_vectors_gpt2(teacher, tokenizer_t, [x[0] for x in teacher_heads])
student_head_vecs = get_head_vectors_distilbert(student, tokenizer_s, [x[0] for x in student_heads])

teacher_mlp_vecs = get_mlp_vectors_gpt2(teacher, tokenizer_t, [x[0] for x in teacher_mlp])
student_mlp_vecs = get_mlp_vectors_distilbert(student, tokenizer_s, [x[0] for x in student_mlp])

attn_matches = compute_best_matches_attn(teacher_head_vecs, student_head_vecs)
mlp_matches = compute_best_matches_mlp(teacher_mlp_vecs, student_mlp_vecs)

matches = {**attn_matches, **mlp_matches}
all_pairs = []
for teacher_comp, (student_comp, sim_score) in matches.items():
    I_T = influence_teacher.get(teacher_comp, 0)
    I_S = influence_student.get(student_comp, 0)
    all_pairs.append((I_S, I_T, sim_score))

scaled = [(I_S * len(all_pairs), I_T * len(all_pairs), S) for (I_S, I_T, S) in all_pairs]
sum_I_S = sum(x[0] for x in scaled)
sum_I_T = sum(x[1] for x in scaled)
normalized = [(I_S / sum_I_S, I_T / sum_I_T, S) for (I_S, I_T, S) in scaled]

alignment_score = compute_alignment_score(normalized)
print(f"Alignment score: {alignment_score:.4f}")
# Out:
# Alignment score: 0.7247

# %%
# import torch
# import numpy as np
# from transformers import AutoTokenizer, BertForMaskedLM, DistilBertForMaskedLM
# from typing import List, Tuple, Dict
# from scipy.linalg import svd
# from sklearn.metrics.pairwise import cosine_similarity as sklearn_cosine_similarity

# device = "cuda" if torch.cuda.is_available() else "cpu"

# # Load models
# bert_model = BertForMaskedLM.from_pretrained("bert-base-uncased").to(device)
# distilbert_model = DistilBertForMaskedLM.from_pretrained("distilbert-base-uncased").to(device)
# bert_tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# distilbert_tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
# bert_model.eval()
# distilbert_model.eval()

# # IOI data
# # texts = [
# #     "Then, Kimberly and Tiffany had a long argument, and afterwards Kimberly said to [MASK].",
# #     "Then, Joshua and Allison had a lot of fun at the restaurant. Joshua gave a bone to [MASK]."
# # ]

# texts = ['After Mark and Sara went to the office, Mark gave a kiss to Sara', 'Then, Brittany and Bryan had a lot of fun at the house. Brittany gave a snack to Bryan', 'Then, Emily and Kimberly went to the station. Kimberly gave a bone to Emily', 'Then, Christine and Stephanie went to the hospital. Christine gave a snack to Stephanie', 'When Emily and Christine got a necklace at the hospital, Christine decided to give it to Emily', 'Then, Megan and Robert were working at the station. Robert decided to give a basketball to Megan', 'Then, Jacob and Tyler were thinking about going to the house. Tyler wanted to give a necklace to Jacob', 'Then, Erin and Lauren had a lot of fun at the station. Lauren gave a basketball to Erin', 'After Brittany and Kevin went to the hospital, Brittany gave a ring to Kevin', 'Then, James and Nicole had a lot of fun at the house. James gave a snack to Nicole', 'Then, Adam and Bradley had a lot of fun at the station. Adam gave a snack to Bradley', 'When Jessica and Robert got a drink at the school, Robert decided to give it to Jessica', 'When Rachel and Megan got a snack at the office, Rachel decided to give it to Megan', 'Then, Danielle and Nathan had a lot of fun at the office. Danielle gave a necklace to Nathan', 'When Steven and Rebecca got a basketball at the hospital, Steven decided to give it to Rebecca', 'Then, Courtney and Nicole went to the garden. Nicole gave a bone to Courtney', 'After Heather and Alicia went to the hospital, Alicia gave a computer to Heather', 'Then, Nicole and Christina went to the office. Christina gave a bone to Nicole', 'Then, Shannon and Christopher were working at the restaurant. Shannon decided to give a computer to Christopher', 'Then, Joshua and Paul had a lot of fun at the restaurant. Paul gave a snack to Joshua', 'Then, Christopher and Scott went to the station. Scott gave a snack to Christopher', 'When Brittany and Brian got a snack at the hospital, Brian decided to give it to Brittany', 'Then, Daniel and Tiffany went to the garden. Tiffany gave a ring to Daniel', 'Then, Tyler and Sarah had a long argument, and afterwards Tyler said to Sarah', 'Then, Angela and Bradley went to the school. Bradley gave a drink to Angela', 'When Aaron and Kyle got a computer at the house, Kyle decided to give it to Aaron', 'Then, Amanda and Travis were thinking about going to the garden. Amanda wanted to give a basketball to Travis', 'Then, Heather and Kevin had a long argument, and afterwards Kevin said to Heather', 'After Stephanie and Paul went to the restaurant, Paul gave a ring to Stephanie', 'Then, Katie and Charles went to the station. Katie gave a computer to Charles', 'Then, Elizabeth and Timothy had a lot of fun at the hospital. Timothy gave a snack to Elizabeth', 'Then, Jesse and Elizabeth went to the school. Elizabeth gave a drink to Jesse', 'Then, Dustin and Eric went to the restaurant. Eric gave a computer to Dustin', 'Then, Justin and David were working at the restaurant. David decided to give a computer to Justin', 'Then, Tyler and Cody were thinking about going to the station. Tyler wanted to give a kiss to Cody', 'When Katie and Kyle got a computer at the house, Kyle decided to give it to Katie', 'Then, Erin and Dustin had a lot of fun at the garden. Erin gave a ring to Dustin', 'Then, Lauren and Alicia went to the hospital. Lauren gave a ring to Alicia', 'Then, Elizabeth and Alexander went to the store. Alexander gave a computer to Elizabeth', 'Then, Bradley and Jennifer were thinking about going to the restaurant. Bradley wanted to give a snack to Jennifer', 'Then, Aaron and Lindsey had a lot of fun at the restaurant. Aaron gave a drink to Lindsey', 'Then, Sean and Robert had a long argument, and afterwards Robert said to Sean', 'After Jose and Lauren went to the restaurant, Jose gave a necklace to Lauren', 'Then, Erin and Katie went to the house. Erin gave a ring to Katie', 'When Robert and Laura got a kiss at the office, Laura decided to give it to Robert', 'Then, Tiffany and Kelly were thinking about going to the station. Kelly wanted to give a drink to Tiffany', 'Then, Nicole and Samantha had a lot of fun at the station. Samantha gave a snack to Nicole', 'Then, Joshua and Anthony were thinking about going to the restaurant. Anthony wanted to give a computer to Joshua', 'When Lindsay and Sean got a basketball at the store, Sean decided to give it to Lindsay', 'When Rachel and William got a drink at the store, Rachel decided to give it to William', 'Then, Eric and Andrew went to the garden. Andrew gave a bone to Eric', 'When Vanessa and Christina got a drink at the hospital, Christina decided to give it to Vanessa', 'Then, Patrick and Stephen were working at the station. Stephen decided to give a bone to Patrick', 'Then, Gregory and Nicole went to the restaurant. Gregory gave a kiss to Nicole', 'Then, Benjamin and Samuel were working at the hospital. Benjamin decided to give a ring to Samuel', 'Then, Kyle and Courtney were working at the station. Kyle decided to give a bone to Courtney', 'When Sara and Patrick got a drink at the office, Patrick decided to give it to Sara', 'When Lauren and Nicole got a drink at the school, Nicole decided to give it to Lauren', 'After Jeremy and Jennifer went to the station, Jennifer gave a drink to Jeremy', 'Then, Lindsey and Kristen went to the station. Lindsey gave a ring to Kristen', 'Then, Andrea and Jamie had a long argument, and afterwards Andrea said to Jamie', 'Then, Nathan and Rebecca went to the restaurant. Rebecca gave a drink to Nathan', 'Then, Lindsey and Sarah were working at the station. Sarah decided to give a computer to Lindsey', 'After Katie and Travis went to the garden, Katie gave a necklace to Travis', 'Then, Alexander and Sara were working at the office. Sara decided to give a snack to Alexander', 'Then, Dustin and Ashley were working at the garden. Ashley decided to give a basketball to Dustin', 'Then, Jesse and Timothy had a long argument, and afterwards Timothy said to Jesse', 'Then, Bradley and Kenneth went to the garden. Kenneth gave a snack to Bradley', 'Then, Kyle and Katie had a long argument, and afterwards Kyle said to Katie', 'Then, Amanda and Christina were thinking about going to the office. Christina wanted to give a drink to Amanda', 'Then, Nathan and Megan had a long argument, and afterwards Nathan said to Megan', 'Then, Mary and James had a long argument, and afterwards Mary said to James', 'Then, Elizabeth and Justin were thinking about going to the hospital. Elizabeth wanted to give a snack to Justin', 'Then, Christopher and Jose were working at the hospital. Christopher decided to give a bone to Jose', 'Then, Aaron and Danielle went to the hospital. Danielle gave a drink to Aaron', 'When Rebecca and Melissa got a drink at the school, Rebecca decided to give it to Melissa', 'Then, Patrick and Joseph were working at the house. Joseph decided to give a necklace to Patrick', 'Then, Kristen and Jessica were thinking about going to the hospital. Kristen wanted to give a ring to Jessica', 'Then, Cody and Jesse were thinking about going to the station. Cody wanted to give a computer to Jesse', 'Then, Elizabeth and Erica were thinking about going to the school. Erica wanted to give a basketball to Elizabeth', 'Then, Alexander and Melissa were thinking about going to the restaurant. Alexander wanted to give a kiss to Melissa', 'Then, Bryan and Jennifer had a long argument, and afterwards Jennifer said to Bryan', 'Then, Christine and Kimberly were thinking about going to the garden. Christine wanted to give a computer to Kimberly', 'After Benjamin and Cody went to the school, Benjamin gave a bone to Cody', 'Then, Dustin and Kimberly were thinking about going to the hospital. Kimberly wanted to give a bone to Dustin', 'Then, Christina and Patrick were working at the office. Christina decided to give a kiss to Patrick', 'When David and Justin got a drink at the school, Justin decided to give it to David', 'Then, Angela and Kimberly were working at the house. Kimberly decided to give a ring to Angela', 'Then, Ryan and Sara were working at the office. Ryan decided to give a computer to Sara', 'Then, Kenneth and Amy were thinking about going to the garden. Kenneth wanted to give a basketball to Amy', 'When Matthew and Travis got a basketball at the office, Travis decided to give it to Matthew', 'Then, Daniel and Kenneth had a long argument, and afterwards Kenneth said to Daniel', 'Then, Jason and Jennifer went to the hospital. Jennifer gave a snack to Jason', 'Then, John and Adam went to the restaurant. Adam gave a drink to John', 'When Jeffrey and Jose got a bone at the house, Jose decided to give it to Jeffrey', 'Then, John and Lindsey went to the house. John gave a computer to Lindsey', 'Then, Katie and Jeffrey had a lot of fun at the station. Jeffrey gave a snack to Katie', 'After Kimberly and John went to the office, John gave a necklace to Kimberly', 'Then, Michelle and Thomas had a lot of fun at the garden. Thomas gave a snack to Michelle', 'Then, Kristen and Heather went to the store. Heather gave a ring to Kristen']





# import re

# def process_texts(texts, tokenizer):
#     masked_texts = []
#     correct_tokens = []
#     incorrect_tokens = []

#     for text in texts:
#         candidates = re.findall(r'\b[A-Z][a-z]+\b', text)
#         filtered_names = [word for word in candidates if word.lower() not in {'after', 'then'}]

#         if len(filtered_names) < 2:
#             raise ValueError(f"Text does not contain at least two valid names: '{text}'")

#         first_name = filtered_names[0]
#         second_name = filtered_names[1]

#         parts = text.rsplit(second_name, 1)
#         if len(parts) == 2:
#             masked_text = parts[0].rstrip() + f" {tokenizer.mask_token} " + parts[1].lstrip()
#         else:
#             raise ValueError(f"Second name '{second_name}' not found in text: '{text}'")

#         masked_texts.append(masked_text)
#         correct_tokens.append(second_name)
#         incorrect_tokens.append(first_name)

#     return masked_texts, correct_tokens, incorrect_tokens

# texts, targets, distractors = process_texts(texts, bert_tokenizer)


# print(f"Texts: {texts[:3]}")
# print(f"Targets: {targets[:3]}")
# print(f"Distractors: {distractors[:3]}")


# def compute_logit_diff_ioi(model, tokenizer, texts, targets, distractors):
#     inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
#     mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)

#     with torch.no_grad():
#         logits = model(**inputs).logits

#     diffs = []
#     for i, (b, pos) in enumerate(zip(*mask_token_index)):
#         logits_slice = logits[b, pos]

#         # Tokenize and get ID sequences
#         tgt_tokens = tokenizer.tokenize(targets[i])
#         dst_tokens = tokenizer.tokenize(distractors[i])
#         tgt_ids = tokenizer.convert_tokens_to_ids(tgt_tokens)
#         dst_ids = tokenizer.convert_tokens_to_ids(dst_tokens)

#         # Average logits for each name
#         tgt_logit = logits_slice[tgt_ids].mean()
#         dst_logit = logits_slice[dst_ids].mean()
#         diffs.append((tgt_logit - dst_logit).item())

#     return np.mean(diffs)


# bert_diff = compute_logit_diff_ioi(bert_model, bert_tokenizer, texts, targets, distractors)
# distilbert_diff = compute_logit_diff_ioi(distilbert_model, distilbert_tokenizer, texts, targets, distractors)

# print(f"BERT logit difference: {bert_diff:.4f}")
# print(f"DistilBERT logit difference: {distilbert_diff:.4f}")

# # === Step 2: Component impact via ablation ===
# def get_logits(model, tokenizer, texts):
#     inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
#     mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)
#     with torch.no_grad():
#         outputs = model(**inputs, return_dict=True)
#     return outputs.logits, inputs, mask_token_index

# def compute_logit_diff_ioi_logits(logits, input_ids, mask_token_index, tokenizer, targets, distractors):
#     diffs = []
#     for i, (b, pos) in enumerate(zip(*mask_token_index)):
#         tgt_tokens = tokenizer.tokenize(targets[i])
#         tgt_ids = tokenizer.convert_tokens_to_ids(tgt_tokens)

#         dst_id = tokenizer.convert_tokens_to_ids(distractors[i])
#         logits_slice = logits[b, pos]
#         #diffs.append((logits_slice[tgt_id] - logits_slice[dst_id]).item())

#         tgt_logit = logits_slice[tgt_ids[0]]  # Or average across all subword logits
#         dst_tokens = tokenizer.tokenize(distractors[i])
#         dst_ids = tokenizer.convert_tokens_to_ids(dst_tokens)
#         dst_logit = logits_slice[dst_ids[0]]

#         tgt_logit = logits_slice[tgt_ids].mean()
#         dst_logit = logits_slice[dst_ids].mean()


#         diffs.append((tgt_logit - dst_logit).item())

#     return np.mean(diffs)




# def get_ablation_hook(head_idx):
#     def ablate_head(module, input, output):
#         if isinstance(output, tuple):
#             attn_output = output[0]
#             attn_output[:, head_idx] = 0
#             return (attn_output,) + output[1:]
#         output[:, head_idx] = 0
#         return output
#     return ablate_head

# def get_mlp_ablation_hook():
#     return lambda module, input, output: torch.zeros_like(output)

# def calculate_head_impacts(model, tokenizer, texts, targets, distractors):
#     is_distilbert = isinstance(model, DistilBertForMaskedLM)
#     logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
#     baseline_diff = compute_logit_diff_ioi_logits(logits, inputs.input_ids, mask_token_index, tokenizer, targets, distractors)
#     num_layers = model.config.num_hidden_layers
#     num_heads = model.config.num_attention_heads
#     impacts = []
#     for layer in range(num_layers):
#         for head in range(num_heads):
#             module = model.distilbert.transformer.layer[layer].attention if is_distilbert else model.bert.encoder.layer[layer].attention.self
#             hook = module.register_forward_hook(get_ablation_hook(head))
#             logits_ablated, _, _ = get_logits(model, tokenizer, texts)
#             ablated_diff = compute_logit_diff_ioi_logits(logits_ablated, inputs.input_ids, mask_token_index, tokenizer, targets, distractors)
#             hook.remove()
#             impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
#             impacts.append(((layer, head), abs(impact)))
#     return impacts

# def calculate_mlp_impacts(model, tokenizer, texts, targets, distractors):
#     is_distilbert = isinstance(model, DistilBertForMaskedLM)
#     logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
#     baseline_diff = compute_logit_diff_ioi_logits(logits, inputs.input_ids, mask_token_index, tokenizer, targets, distractors)
#     impacts = []
#     for layer in range(model.config.num_hidden_layers):
#         module = model.distilbert.transformer.layer[layer].ffn.lin1 if is_distilbert else model.bert.encoder.layer[layer].intermediate.dense
#         hook = module.register_forward_hook(get_mlp_ablation_hook())
#         try:
#             logits_ablated, _, _ = get_logits(model, tokenizer, texts)
#             ablated_diff = compute_logit_diff_ioi_logits(logits_ablated, inputs.input_ids, mask_token_index, tokenizer, targets, distractors)
#             impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
#             impacts.append((layer, abs(impact)))
#         finally:
#             hook.remove()
#     return impacts

# # === Step 3: Component similarity ===
# def get_head_vectors(model, tokenizer, texts, top_heads: List[Tuple[int, int]]):
#     inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
#     with torch.no_grad():
#         outputs = model(**inputs, output_attentions=True, return_dict=True)
#     attentions = outputs.attentions
#     vectors = {}
#     for layer, head in top_heads:
#         vectors[(layer, head)] = attentions[layer][:, head].mean(dim=0)
#     return vectors

# def get_mlp_vectors(model, tokenizer, texts, top_layers: List[int]):
#     inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
#     with torch.no_grad():
#         outputs = model(**inputs, output_hidden_states=True, return_dict=True)
#     hidden_states = outputs.hidden_states
#     vectors = {}
#     for layer in top_layers:
#         vectors[layer] = hidden_states[layer + 1].mean(dim=(0, 1))
#     return vectors

# def activation_eigenvector_similarity(acts1, acts2, k=3):
#     acts1_flat = acts1.reshape(-1, acts1.shape[-1])
#     acts2_flat = acts2.reshape(-1, acts2.shape[-1])
#     cov1 = np.dot(acts1_flat.T, acts1_flat) / acts1_flat.shape[0]
#     cov2 = np.dot(acts2_flat.T, acts2_flat) / acts2_flat.shape[0]
#     U1, _, _ = svd(cov1)
#     U2, _, _ = svd(cov2)
#     sim_matrix = sklearn_cosine_similarity(U1[:, :k].T, U2[:, :k].T)
#     return np.mean(sim_matrix)

# def compute_best_matches_attn(src_dict: Dict, tgt_dict: Dict) -> Dict:
#     matches = {}
#     for s_key, s_mat in src_dict.items():
#         best_sim, best_key = -1, None
#         for t_key, t_mat in tgt_dict.items():
#             sim = torch.nn.functional.cosine_similarity(s_mat.flatten(), t_mat.flatten(), dim=0).item()
#             if sim > best_sim:
#                 best_sim, best_key = sim, t_key
#         matches[s_key] = (best_key, best_sim)
#     return matches

# def compute_best_matches_mlp(src_dict: Dict, tgt_dict: Dict) -> Dict:
#     matches = {}
#     for s_key, s_vec in src_dict.items():
#         best_sim, best_key = -1, None
#         for t_key, t_vec in tgt_dict.items():
#             sim = activation_eigenvector_similarity(s_vec.cpu().numpy(), t_vec.cpu().numpy())
#             if sim > best_sim:
#                 best_sim, best_key = sim, t_key
#         matches[s_key] = (best_key, best_sim)
#     return matches


# def compute_best_matches_attn_biased_to_teacher(teacher_dict: Dict, student_dict: Dict) -> Dict:
#     matches = {}
#     for t_key, t_mat in teacher_dict.items():
#         best_sim, best_key = -1, None
#         for s_key, s_mat in student_dict.items():
#             sim = torch.nn.functional.cosine_similarity(t_mat.flatten(), s_mat.flatten(), dim=0).item()
#             if sim > best_sim:
#                 best_sim, best_key = sim, s_key
#         matches[t_key] = (best_key, best_sim)
#     return matches

# def compute_best_matches_mlp_biased_to_teacher(teacher_dict: Dict, student_dict: Dict) -> Dict:
#     matches = {}
#     for t_key, t_vec in teacher_dict.items():
#         best_sim, best_key = -1, None
#         for s_key, s_vec in student_dict.items():
#             sim = activation_eigenvector_similarity(t_vec.cpu().numpy(), s_vec.cpu().numpy())
#             if sim > best_sim:
#                 best_sim, best_key = sim, s_key
#         matches[t_key] = (best_key, best_sim)
#     return matches


# def compute_alignment_score(pairs: List[Tuple[float, float, float]]) -> float:
#     return sum(S * (1 - abs(I_S - I_T)) for I_S, I_T, S in pairs) / len(pairs)

# # === Run evaluation
# bert_diff = compute_logit_diff_ioi(bert_model, bert_tokenizer, texts, targets, distractors)
# distilbert_diff = compute_logit_diff_ioi(distilbert_model, distilbert_tokenizer, texts, targets, distractors)

# teacher_heads = calculate_head_impacts(bert_model, bert_tokenizer, texts, targets, distractors)
# student_heads = calculate_head_impacts(distilbert_model, distilbert_tokenizer, texts, targets, distractors)
# teacher_mlp = calculate_mlp_impacts(bert_model, bert_tokenizer, texts, targets, distractors)
# student_mlp = calculate_mlp_impacts(distilbert_model, distilbert_tokenizer, texts, targets, distractors)

# influence_teacher = {k: v for k, v in dict(teacher_heads + teacher_mlp).items()}
# influence_student = {k: v for k, v in dict(student_heads + student_mlp).items()}

# # Representations
# student_head_vecs = get_head_vectors(distilbert_model, distilbert_tokenizer, texts, [x[0] for x in student_heads])
# teacher_head_vecs = get_head_vectors(bert_model, bert_tokenizer, texts, [x[0] for x in teacher_heads])
# student_mlp_vecs = get_mlp_vectors(distilbert_model, distilbert_tokenizer, texts, [x[0] for x in student_mlp])
# teacher_mlp_vecs = get_mlp_vectors(bert_model, bert_tokenizer, texts, [x[0] for x in teacher_mlp])

# attn_matches = compute_best_matches_attn_biased_to_teacher(teacher_head_vecs, student_head_vecs)
# mlp_matches = compute_best_matches_mlp_biased_to_teacher(teacher_mlp_vecs, student_mlp_vecs)


# matches = {**attn_matches, **mlp_matches}
# all_pairs = []
# for teacher_comp, (student_comp, sim_score) in matches.items():
#     I_T = influence_teacher.get(teacher_comp, 0)
#     I_S = influence_student.get(student_comp, 0)
#     all_pairs.append((I_S, I_T, sim_score))

# scaled = [(I_S * len(all_pairs), I_T * len(all_pairs), S) for (I_S, I_T, S) in all_pairs]
# sum_I_S = sum(x[0] for x in scaled)
# sum_I_T = sum(x[1] for x in scaled)
# normalized = [(I_S / sum_I_S, I_T / sum_I_T, S) for (I_S, I_T, S) in scaled]

# alignment_score = compute_alignment_score(normalized)

# print(f"Alignment score: {alignment_score:.4f}")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Texts: ['After Mark and Sara went to the office, Mark gave a kiss to [MASK] ', 'Then, Brittany and Bryan had a lot of fun at the house. Brittany gave a snack to [MASK] ', 'Then, Emily and Kimberly went to the station. [MASK] gave a bone to Emily']
# Targets: ['Sara', 'Bryan', 'Kimberly']
# Distractors: ['Mark', 'Brittany', 'Emily']
# BERT logit difference: 2.8142
# DistilBERT logit difference: 3.9520
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-19f0d780214f> in <cell line: 0>()
#     262 distilbert_diff = compute_logit_diff_ioi(distilbert_model, distilbert_tokenizer, texts, targets, distractors)
#     263
# --> 264 teacher_heads = calculate_head_impacts(bert_model, bert_tokenizer, texts, targets, distractors)
#     265 student_heads = calculate_head_impacts(distilbert_model, distilbert_tokenizer, texts, targets, distractors)
#     266 teacher_mlp = calculate_mlp_impacts(bert_model, bert_tokenizer, texts, targets, distractors)
#
# <ipython-input-17-19f0d780214f> in calculate_head_impacts(model, tokenizer, texts, targets, distractors)
#     155             hook = module.register_forward_hook(get_ablation_hook(head))
#     156             logits_ablated, _, _ = get_logits(model, tokenizer, texts)
# --> 157             ablated_diff = compute_logit_diff_ioi_logits(logits_ablated, inputs.input_ids, mask_token_index, tokenizer, targets, distractors)
#     158             hook.remove()
#     159             impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
#
# <ipython-input-17-19f0d780214f> in compute_logit_diff_ioi_logits(logits, input_ids, mask_token_index, tokenizer, targets, distractors)
#     107     diffs = []
#     108     for i, (b, pos) in enumerate(zip(*mask_token_index)):
# --> 109         tgt_tokens = tokenizer.tokenize(targets[i])
#     110         tgt_ids = tokenizer.convert_tokens_to_ids(tgt_tokens)
#     111
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_fast.py in tokenize(self, text, pair, add_special_tokens, **kwargs)
#     419
#     420     def tokenize(self, text: str, pair: Optional[str] = None, add_special_tokens: bool = False, **kwargs) -> list[str]:
# --> 421         return self.encode_plus(text=text, text_pair=pair, add_special_tokens=add_special_tokens, **kwargs).tokens()
#     422
#     423     def set_truncation_and_padding(
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3071         )
#    3072
# -> 3073         return self._encode_plus(
#    3074             text=text,
#    3075             text_pair=text_pair,
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_fast.py in _encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#     611     ) -> BatchEncoding:
#     612         batched_input = [(text, text_pair)] if text_pair else [text]
# --> 613         batched_output = self._batch_encode_plus(
#     614             batched_input,
#     615             is_split_into_words=is_split_into_words,
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_fast.py in _batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens)
#     537             self._tokenizer.encode_special_tokens = split_special_tokens
#     538
# --> 539         encodings = self._tokenizer.encode_batch(
#     540             batch_text_or_text_pairs,
#     541             add_special_tokens=add_special_tokens,
#
# KeyboardInterrupt:

# %%
# texts = ['Van done in one. Hat done in two. Ring done in three. Desk done in four. Sun done in', 'Ice done in two. Snow done in three. Watch done in four. Sun done in five. Table done in', 'Ring done in three. Moon done in four. Queen done in five. Book done in six. Rose done in', 'Queen done in four. Oil done in five. Rose done in six. Desk done in seven. Car done in', 'Light done in five. Arm done in six. Road done in seven. Book done in eight. Ice done in', 'Ball done in six. Cow done in seven. Book done in eight. Rose done in nine. Key done in', 'Road done in seven. Key done in eight. Ocean done in nine. Key done in ten. Queen done in', 'House done in eight. Rose done in nine. Key done in ten. Hat done in eleven. Van done in', 'Ring done in one. Car done in two. Apple done in three. Pear done in four. Moon done in', 'Star done in two. Sun done in three. Road done in four. Queen done in five. Box done in', 'Hill done in three. Ant done in four. Apple done in five. House done in six. Hat done in', 'Chair done in four. Van done in five. Orange done in six. Queen done in seven. Zip done in', 'Gate done in five. Desk done in six. Wolf done in seven. Rain done in eight. Flag done in', 'Queen done in six. House done in seven. Light done in eight. Cat done in nine. Moon done in', 'Zip done in seven. Car done in eight. Ring done in nine. Hand done in ten. Fish done in', 'Snake done in eight. Queen done in nine. Window done in ten. Ear done in eleven. Orange done in', 'Ice done in one. Sand done in two. Desk done in three. Van done in four. Hat done in', 'Camera done in two. Watch done in three. Dog done in four. Book done in five. Desk done in', 'Rain done in three. Dog done in four. Rat done in five. Nut done in six. Ocean done in', 'Night done in four. Hat done in five. Wall done in six. Book done in seven. Tree done in', 'Gate done in five. Chair done in six. Ring done in seven. Hill done in eight. Car done in', 'Ax done in six. Fan done in seven. Cat done in eight. Ring done in nine. Ring done in', 'Rose done in seven. Night done in eight. Van done in nine. Orange done in ten. Apple done in', 'Orange done in eight. Ear done in nine. Book done in ten. Ring done in eleven. Bird done in', 'Ball done in one. Wind done in two. Wallet done in three. Tree done in four. Sand done in', 'Table done in two. Jam done in three. Apple done in four. Pear done in five. Ice done in', 'Gate done in three. Train done in four. Hat done in five. Fan done in six. Key done in', 'Window done in four. Desk done in five. Year done in six. Van done in seven. Camera done in', 'Car done in five. Watch done in six. Oil done in seven. Queen done in eight. Fan done in', 'Mouse done in six. Rose done in seven. Table done in eight. Clock done in nine. Queen done in', 'Year done in seven. Wheel done in eight. Wolf done in nine. Arm done in ten. Ax done in', 'Key done in eight. Ring done in nine. Night done in ten. Fan done in eleven. Clock done in', 'Glass done in one. Key done in two. Nut done in three. Rat done in four. Van done in', 'Star done in two. Pear done in three. Bug done in four. Bird done in five. Ring done in', 'Road done in three. Wind done in four. Rat done in five. Wolf done in six. Map done in', 'Car done in four. Ant done in five. Rose done in six. Van done in seven. Wolf done in', 'Zip done in five. Hat done in six. Wind done in seven. Rain done in eight. Car done in', 'Ring done in six. Light done in seven. Jar done in eight. Dog done in nine. Fish done in', 'Bug done in seven. Key done in eight. Gate done in nine. Orange done in ten. Ring done in', 'Flag done in eight. Fire done in nine. Pear done in ten. Ax done in eleven. Ear done in', 'Ring done in one. Flag done in two. Queen done in three. Map done in four. Camera done in', 'Desk done in two. Fire done in three. Desk done in four. Road done in five. Watch done in', 'Queen done in three. House done in four. Flag done in five. Tree done in six. Ring done in', 'Desk done in four. Window done in five. Fish done in six. Jar done in seven. Hat done in', 'Snake done in five. Key done in six. Glass done in seven. Van done in eight. House done in', 'Camera done in six. Year done in seven. Rose done in eight. Map done in nine. Fire done in', 'Rose done in seven. Snake done in eight. Corn done in nine. Desk done in ten. Zip done in', 'Table done in eight. Key done in nine. Eye done in ten. Van done in eleven. Key done in', 'Star done in one. Hat done in two. Star done in three. Eye done in four. Gold done in', 'Gate done in two. Queen done in three. Camera done in four. Zip done in five. Ocean done in', 'Fan done in three. Corn done in four. Apple done in five. Van done in six. Cat done in', 'Key done in four. Gold done in five. Star done in six. Queen done in seven. Arm done in', 'Van done in five. Snake done in six. Car done in seven. Star done in eight. Watch done in', 'Jar done in six. Flag done in seven. Window done in eight. Sun done in nine. Van done in', 'Wolf done in seven. Watch done in eight. Ring done in nine. Desk done in ten. Car done in', 'Cow done in eight. Tree done in nine. Book done in ten. Wall done in eleven. Flag done in', 'Van done in one. Wall done in two. Ring done in three. Car done in four. Key done in', 'Jar done in two. Wallet done in three. Fish done in four. Watch done in five. Orange done in', 'Watch done in three. Orange done in four. Table done in five. Corn done in six. Van done in', 'Lake done in four. Star done in five. Fan done in six. Fan done in seven. Night done in', 'Fan done in five. Ball done in six. Desk done in seven. Jam done in eight. Tree done in', 'Key done in six. Jar done in seven. Night done in eight. Fish done in nine. Fan done in', 'Ice done in seven. Rose done in eight. Wall done in nine. Road done in ten. Window done in', 'Tree done in eight. Hill done in nine. Wall done in ten. Queen done in eleven. Desk done in', 'Gold done in one. King done in two. Queen done in three. Desk done in four. Night done in', 'Van done in two. Sand done in three. Tree done in four. Car done in five. Cow done in', 'Pear done in three. Eye done in four. Lake done in five. Fan done in six. Light done in', 'Jam done in four. Road done in five. Corn done in six. Ice done in seven. Pen done in', 'Iron done in five. Ring done in six. Star done in seven. Van done in eight. Star done in', 'Bird done in six. Wheel done in seven. Cat done in eight. Desk done in nine. Desk done in', 'Fish done in seven. Gold done in eight. King done in nine. Ax done in ten. Jam done in', 'Desk done in eight. House done in nine. Cow done in ten. Hill done in eleven. Gate done in', 'Nut done in one. Light done in two. Sand done in three. Wall done in four. Key done in', 'Tree done in two. Fan done in three. Car done in four. Desk done in five. Ring done in', 'Orange done in three. Ocean done in four. Sun done in five. Bug done in six. Queen done in', 'Orange done in four. House done in five. Watch done in six. Corn done in seven. Ring done in', 'Wind done in five. Orange done in six. Rose done in seven. Zip done in eight. Queen done in', 'Iron done in six. Cat done in seven. Glass done in eight. Box done in nine. Rose done in', 'Clock done in seven. Zip done in eight. Cat done in nine. Snow done in ten. Ant done in', 'Rose done in eight. Ear done in nine. Rose done in ten. Rat done in eleven. Orange done in', 'Road done in one. Ring done in two. Pen done in three. Oil done in four. Camera done in', 'House done in two. Zip done in three. Queen done in four. Snow done in five. Lake done in', 'Van done in three. Tree done in four. Wall done in five. Rat done in six. King done in', 'Ball done in four. Hill done in five. Clock done in six. Ear done in seven. Van done in', 'Night done in five. Ice done in six. Apple done in seven. Tree done in eight. House done in', 'Clock done in six. Orange done in seven. Queen done in eight. Desk done in nine. Arm done in', 'Map done in seven. Sun done in eight. Clock done in nine. Cat done in ten. Ball done in', 'Desk done in eight. Key done in nine. Star done in ten. Cow done in eleven. Rose done in', 'Ring done in one. Fan done in two. Window done in three. Tree done in four. Chair done in', 'House done in two. Nut done in three. Queen done in four. Zip done in five. Rose done in', 'Window done in three. Gate done in four. Zip done in five. Key done in six. Snow done in', 'Corn done in four. Ice done in five. Eye done in six. Light done in seven. Desk done in', 'Hill done in five. Snake done in six. Orange done in seven. Road done in eight. Flag done in', 'Queen done in six. Window done in seven. Zip done in eight. Cow done in nine. Fire done in', 'Star done in seven. Hat done in eight. Chair done in nine. Car done in ten. Ring done in', 'Desk done in eight. Watch done in nine. Desk done in ten. Ax done in eleven. Queen done in', 'Train done in one. Snow done in two. Cow done in three. Ring done in four. Queen done in', 'Window done in two. Pen done in three. Ax done in four. Iron done in five. Nut done in', 'Desk done in three. Flag done in four. Fan done in five. Hat done in six. Chair done in', 'King done in four. Star done in five. Cow done in six. Wallet done in seven. Fan done in', 'Star done in five. Watch done in six. Car done in seven. Van done in eight. Queen done in']


# import torch
# import numpy as np
# import re
# from transformers import AutoTokenizer, BertForMaskedLM, DistilBertForMaskedLM

# # Set device
# device = "cuda" if torch.cuda.is_available() else "cpu"

# # Load models and tokenizers
# bert_model = BertForMaskedLM.from_pretrained("bert-base-uncased").to(device)
# bert_tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# distilbert_model = DistilBertForMaskedLM.from_pretrained("distilbert-base-uncased").to(device)
# distilbert_tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# bert_model.eval()
# distilbert_model.eval()

# # Tokens to compare
# target_token = 'five'
# distractor_token = 'four'

# # === Normalize text (to word numerals like 'five') ===
# def normalize_numerals(texts):
#     number_words = [
#         'zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten',
#         'eleven', 'twelve', 'thirteen', 'fourteen', 'fifteen', 'sixteen', 'seventeen', 'eighteen',
#         'nineteen', 'twenty'
#     ]
#     pattern = r'\b(?:' + '|'.join(number_words) + r')\b'
#     normalized_texts = []
#     for text in texts:
#         matches = list(re.finditer(pattern, text, flags=re.IGNORECASE))
#         mapping = {match.group().lower(): number_words[i] for i, match in enumerate(matches)}
#         def replacement(match): return mapping[match.group().lower()]
#         normalized_texts.append(re.sub(pattern, replacement, text, flags=re.IGNORECASE))
#     return normalized_texts

# # === Input texts ===
# texts = [t + " [MASK]" for t in normalize_numerals(texts)]

# # === Compute logits and logit difference ===
# def compute_logit_diff(model, tokenizer, texts, target_token, distractor_token):
#     inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
#     mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)
#     with torch.no_grad():
#         logits = model(**inputs).logits
#     diffs = []
#     for b, pos in zip(*mask_token_index):
#         logits_slice = logits[b, pos]
#         target_logit = logits_slice[tokenizer.convert_tokens_to_ids(target_token)]
#         distractor_logit = logits_slice[tokenizer.convert_tokens_to_ids(distractor_token)]
#         diffs.append((target_logit - distractor_logit).item())
#     return np.mean(diffs)

# # === Run for both models ===
# bert_diff = compute_logit_diff(bert_model, bert_tokenizer, texts, target_token, distractor_token)
# distilbert_diff = compute_logit_diff(distilbert_model, distilbert_tokenizer, texts, target_token, distractor_token)

# print(f"BERT logit difference: {bert_diff:.4f}")
# print(f"DistilBERT logit difference: {distilbert_diff:.4f}")












# import torch
# import numpy as np
# import re
# import matplotlib.pyplot as plt
# from typing import List, Tuple, Dict
# from torch.nn.functional import cosine_similarity
# from transformers import (AutoTokenizer, BertForMaskedLM, DistilBertForMaskedLM)

# # Setup

# device = "cuda" if torch.cuda.is_available() else "cpu"
# teacher_str = "bert-base-uncased"
# student_str = "distilbert-base-uncased"

# teacher = BertForMaskedLM.from_pretrained(teacher_str).to(device)
# student = DistilBertForMaskedLM.from_pretrained(student_str).to(device)
# tokenizer_t = AutoTokenizer.from_pretrained(teacher_str)
# tokenizer_s = AutoTokenizer.from_pretrained(student_str)

# teacher.eval()
# student.eval()

# target_token = 'five'
# distractor_token = 'four'

# # Text normalization and formatting
# def normalize_numerals(texts):
#     number_words = [
#         'zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten',
#         'eleven', 'twelve', 'thirteen', 'fourteen', 'fifteen', 'sixteen', 'seventeen', 'eighteen',
#         'nineteen', 'twenty'
#     ]

#     pattern = r'\b(?:' + '|'.join(number_words) + r')\b'
#     normalized_texts = []

#     for text in texts:
#         matches = list(re.finditer(pattern, text, flags=re.IGNORECASE))
#         mapping = {match.group().lower(): number_words[i] for i, match in enumerate(matches)}

#         def replacement(match):
#             return mapping[match.group().lower()]

#         normalized_text = re.sub(pattern, replacement, text, flags=re.IGNORECASE)
#         normalized_texts.append(normalized_text)

#     return normalized_texts

# texts = [t + " [MASK]" for t in normalize_numerals(texts)]

# # Helper functions
# def get_logits(model, tokenizer, texts):
#     inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
#     mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)
#     with torch.no_grad():
#         outputs = model(**inputs, return_dict=True)
#     return outputs.logits, inputs, mask_token_index

# def compute_logit_diff(logits, input_ids, mask_token_index, tokenizer):
#     diffs = []
#     for b, pos in zip(*mask_token_index):
#         logits_slice = logits[b, pos]
#         correct_logit = logits_slice[tokenizer.convert_tokens_to_ids(target_token)]
#         incorrect_logit = logits_slice[tokenizer.convert_tokens_to_ids(distractor_token)]
#         diffs.append((correct_logit - incorrect_logit).item())
#     return np.mean(diffs)

# # Component ablation hooks
# def get_ablation_hook(head_idx):
#     def ablate_head(module, input, output):
#         if isinstance(output, tuple):
#             attn_output = output[0]
#             attn_output[:, head_idx] = 0
#             return (attn_output,) + output[1:]
#         output[:, head_idx] = 0
#         return output
#     return ablate_head

# def get_mlp_ablation_hook():
#     return lambda module, input, output: torch.zeros_like(output)

# # Impact calculations
# def calculate_head_impacts(model, tokenizer, name='model'):
#     is_distilbert = isinstance(model, DistilBertForMaskedLM)
#     logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
#     baseline_diff = compute_logit_diff(logits, inputs.input_ids, mask_token_index, tokenizer)
#     num_layers = model.config.num_hidden_layers
#     num_heads = model.config.num_attention_heads
#     impacts = []
#     for layer in range(num_layers):
#         for head in range(num_heads):
#             module = (model.distilbert.transformer.layer[layer].attention
#                       if is_distilbert
#                       else model.bert.encoder.layer[layer].attention.self)
#             hook = module.register_forward_hook(get_ablation_hook(head))
#             logits_ablated, _, _ = get_logits(model, tokenizer, texts)
#             ablated_diff = compute_logit_diff(logits_ablated, inputs.input_ids, mask_token_index, tokenizer)
#             hook.remove()
#             impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
#             impacts.append(((layer, head), abs(impact)))  # use absolute value like old_am.py
#     return impacts

# def calculate_mlp_impacts(model, tokenizer, name='model'):
#     is_distilbert = isinstance(model, DistilBertForMaskedLM)
#     logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
#     baseline_diff = compute_logit_diff(logits, inputs.input_ids, mask_token_index, tokenizer)
#     impacts = []
#     for layer in range(model.config.num_hidden_layers):
#         module = (model.distilbert.transformer.layer[layer].ffn.lin1
#                   if is_distilbert
#                   else model.bert.encoder.layer[layer].intermediate.dense)
#         hook = module.register_forward_hook(get_mlp_ablation_hook())
#         try:
#             logits_ablated, _, _ = get_logits(model, tokenizer, texts)
#             ablated_diff = compute_logit_diff(logits_ablated, inputs.input_ids, mask_token_index, tokenizer)
#             impact = 100 * (1 - ablated_diff / baseline_diff) if baseline_diff != 0 else 0
#             impacts.append((layer, abs(impact)))  # use absolute value like old_am.py
#         finally:
#             hook.remove()
#     return impacts

# # Representation collection
# def get_head_vectors(model, tokenizer, top_heads: List[Tuple[int, int]]):
#     is_distilbert = isinstance(model, DistilBertForMaskedLM)
#     inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
#     with torch.no_grad():
#         outputs = model(**inputs, output_attentions=True, return_dict=True)
#     attentions = outputs.attentions
#     vectors = {}
#     for layer, head in top_heads:
#         tensor = attentions[layer][:, head]  # shape: [batch, seq_len, seq_len]
#         vectors[(layer, head)] = tensor.mean(dim=0)  # shape: [seq_len, seq_len]
#     return vectors


# def get_mlp_vectors(model, tokenizer, top_layers: List[int]):
#     inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
#     with torch.no_grad():
#         outputs = model(**inputs, output_hidden_states=True, return_dict=True)
#     hidden_states = outputs.hidden_states
#     vectors = {}
#     for layer in top_layers:
#         mlp_output = hidden_states[layer + 1]
#         vectors[layer] = mlp_output.mean(dim=(0, 1))
#     return vectors

# import torch.nn.functional as F

# def compute_best_matches_attn(src_dict: Dict, tgt_dict: Dict, threshold=0.0) -> Dict:
#     matches = {}
#     for s_key, s_mat in src_dict.items():  # s_mat: [seq_len, seq_len]
#         best_sim, best_key = -1, None
#         for t_key, t_mat in tgt_dict.items():
#             sim = torch.mean(F.cosine_similarity(s_mat.unsqueeze(1), t_mat.unsqueeze(1), dim=2)).item()
#             if sim > best_sim:
#                 best_sim, best_key = sim, t_key
#         if best_sim >= threshold:
#             matches[s_key] = (best_key, best_sim)
#     return matches

# import numpy as np
# from scipy.linalg import svd
# from sklearn.metrics.pairwise import cosine_similarity

# def activation_eigenvector_similarity(acts1, acts2, k=3):
#     acts1_flat = acts1.reshape(-1, acts1.shape[-1])
#     acts2_flat = acts2.reshape(-1, acts2.shape[-1])

#     cov1 = np.dot(acts1_flat.T, acts1_flat) / acts1_flat.shape[0]
#     cov2 = np.dot(acts2_flat.T, acts2_flat) / acts2_flat.shape[0]

#     U1, _, _ = svd(cov1)
#     U2, _, _ = svd(cov2)
#     U1_topk = U1[:, :k]
#     U2_topk = U2[:, :k]

#     sim_matrix = cosine_similarity(U1_topk.T, U2_topk.T)
#     return np.mean(sim_matrix)

# def compute_best_matches_mlp(src_dict: Dict, tgt_dict: Dict, threshold=0.0) -> Dict:
#     matches = {}
#     for s_key, s_vec in src_dict.items():
#         best_sim, best_key = -1, None
#         for t_key, t_vec in tgt_dict.items():
#             sim = activation_eigenvector_similarity(s_vec.cpu().numpy(), t_vec.cpu().numpy())
#             if sim > best_sim:
#                 best_sim, best_key = sim, t_key
#         if best_sim >= threshold:
#             matches[s_key] = (best_key, best_sim)
#     return matches



# def compute_alignment_score(pairs: List[Tuple[float, float, float]]) -> float:
#     return sum(S * (1 - abs(I_S - I_T)) for I_S, I_T, S in pairs) / len(pairs)

# # === Run pipeline ===
# teacher_heads = calculate_head_impacts(teacher, tokenizer_t, name="Teacher")
# student_heads = calculate_head_impacts(student, tokenizer_s, name="Student")
# teacher_mlp = calculate_mlp_impacts(teacher, tokenizer_t, name="Teacher")
# student_mlp = calculate_mlp_impacts(student, tokenizer_s, name="Student")

# influence_teacher = {k: abs(v) for k, v in dict(teacher_heads + teacher_mlp).items()}
# influence_student = {k: abs(v) for k, v in dict(student_heads + student_mlp).items()}

# teacher_head_vecs = get_head_vectors(teacher, tokenizer_t, [x[0] for x in teacher_heads])
# student_head_vecs = get_head_vectors(student, tokenizer_s, [x[0] for x in student_heads])

# teacher_mlp_vecs = get_mlp_vectors(teacher, tokenizer_t, [x[0] for x in teacher_mlp])
# student_mlp_vecs = get_mlp_vectors(student, tokenizer_s, [x[0] for x in student_mlp])

# attn_matches = compute_best_matches_attn(student_head_vecs, teacher_head_vecs, threshold=0.0)
# mlp_matches = compute_best_matches_mlp(student_mlp_vecs, teacher_mlp_vecs, threshold=0.0)


# matches = {**attn_matches, **mlp_matches}
# all_pairs = []
# for student_comp, (teacher_comp, sim_score) in matches.items():
#     I_S = influence_student.get(student_comp, 0)
#     I_T = influence_teacher.get(teacher_comp, 0)
#     all_pairs.append((I_S, I_T, sim_score))

# scaled = [(I_S * len(all_pairs), I_T * len(all_pairs), S) for (I_S, I_T, S) in all_pairs]
# sum_I_S = sum(x[0] for x in scaled)
# sum_I_T = sum(x[1] for x in scaled)
# normalized = [(I_S / sum_I_S, I_T / sum_I_T, S) for (I_S, I_T, S) in scaled]
# final_pairs = normalized

# print(final_pairs)

# alignment_score = compute_alignment_score(final_pairs)
# print(f"Alignment score: {round(alignment_score, 4)}")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# BERT logit difference: -0.4300
# DistilBERT logit difference: -1.1543
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [(np.float64(0.017818296775565776), np.float64(0.00035866619751002277), 0.897171139717102), (np.float64(0.0024372830374506994), np.float64(0.0038654735620721604), 0.9348768591880798), (np.float64(0.011996833389528288), np.float64(0.023223078025618873), 0.903052031993866), (np.float64(0.002658363820474686), np.float64(0.0025722119261438457), 0.9283496737480164), (np.float64(0.008841145895500441), np.float64(0.01706510142518007), 0.893366813659668), (np.float64(0.006961365646234359), np.float64(0.004405335128209073), 0.8824284672737122), (np.float64(0.0033085342690110583), np.float64(0.004251838361435152), 0.8857174515724182), (np.float64(0.018699241703915688), np.float64(0.006496223941084865), 0.8824194669723511), (np.float64(0.0025866659942316798), np.float64(0.01441218870754137), 0.8517544865608215), (np.float64(0.01934920881811888), np.float64(0.010417680946666043), 0.7856296896934509), (np.float64(0.00354256281160934), np.float64(0.004760596940412123), 0.9380377531051636), (np.float64(0.0030195098536431636), np.float64(0.003482944512700758), 0.8411242365837097), (np.float64(0.011834373538035072), np.float64(0.011660521453773547), 0.999976396560669), (np.float64(0.004242874793255709), np.float64(0.0007048357220126194), 0.8223454356193542), (np.float64(0.013245118556943871), np.float64(0.006543505868813537), 0.9419341087341309), (np.float64(0.005878939937672056), np.float64(0.002629012058389274), 0.9140171408653259), (np.float64(0.015320554949593864), np.float64(0.020500434270743533), 0.9116518497467041), (np.float64(0.0014763592245936124), np.float64(0.018664294219339538), 0.885077178478241), (np.float64(0.0009175094356334331), np.float64(0.0023637238833084393), 0.9618883728981018), (np.float64(0.0032801438019216408), np.float64(0.0008683266649711233), 0.8636060953140259), (np.float64(0.021578053473893143), np.float64(0.010987573867365989), 0.8838430643081665), (np.float64(0.0192331719785266), np.float64(0.011660521453773547), 0.9994840621948242), (np.float64(0.015163540890961037), np.float64(0.013851342730253095), 0.9139590859413147), (np.float64(0.0022520090737739393), np.float64(0.01441218870754137), 0.8471782803535461), (np.float64(0.0010355418055060968), np.float64(9.816501941270752e-05), 0.8838561773300171), (np.float64(0.0006740047996548769), np.float64(0.0024148710942105897), 0.8584108948707581), (np.float64(0.004800603746295093), np.float64(0.0011561617244625311), 0.9252964854240417), (np.float64(0.013193978901966791), np.float64(0.0015204146496655862), 0.8356057405471802), (np.float64(0.00834935362926374), np.float64(0.004440072703840777), 0.877934455871582), (np.float64(0.0023634327210911685), np.float64(0.009508268259855932), 0.788686990737915), (np.float64(0.0002527616990420886), np.float64(0.002121850728914814), 0.8685592412948608), (np.float64(0.00888231360670581), np.float64(0.0008109486490517936), 0.8626735210418701), (np.float64(0.001100923425251852), np.float64(0.005612228100382128), 0.918443500995636), (np.float64(0.017963005183044955), np.float64(0.009299444579167832), 0.9077169895172119), (np.float64(0.0006980717367123), np.float64(0.004331244362532014), 0.8503580093383789), (np.float64(0.0019281538438580444), np.float64(0.0031663626896513523), 0.8925238251686096), (np.float64(0.0015521986501494276), np.float64(0.001287221711115298), 0.913192629814148), (np.float64(0.0046239062107560425), np.float64(0.0025509471340917148), 0.9768298864364624), (np.float64(0.0014493999458283092), np.float64(0.0031663626896513523), 0.9278987050056458), (np.float64(0.00395234427691462), np.float64(0.00173612976110748), 0.9798027276992798), (np.float64(0.029636350057910862), np.float64(0.018117614215694185), 0.9637865424156189), (np.float64(0.0023215130295798658), np.float64(5.040384310266154e-06), 0.9210578203201294), (np.float64(0.009167329838621643), np.float64(0.002693503434020823), 0.9800863265991211), (np.float64(0.0015995084851246), np.float64(0.0014006035283680213), 0.9594740867614746), (np.float64(0.001180011205962 ...
# Alignment score: 0.847

# %% [markdown]
# # BERT Numeral sequence completion case study:

# %% [markdown]
# ## Compute head influences & Match heads

# %%
from transformers import AutoModelForMaskedLM, AutoTokenizer
import torch
import torch.nn.functional as F
import numpy as np
from torch.nn.functional import cosine_similarity
import re

device = "cuda" if torch.cuda.is_available() else "cpu"

teacher_str = "bert-base-uncased"
student_str = "distilbert-base-uncased"

teacher = AutoModelForMaskedLM.from_pretrained(teacher_str).to(device)
student = AutoModelForMaskedLM.from_pretrained(student_str).to(device)
tokenizer_t = AutoTokenizer.from_pretrained(teacher_str)
tokenizer_s = AutoTokenizer.from_pretrained(student_str)

teacher.eval()
student.eval()

def normalize_numerals(texts):
    normalized_texts = []

    for text in texts:
        matches = list(re.finditer(r'\b\d+\b', text))
        mapping = {match.group(): str(i + 1) for i, match in enumerate(matches)}

        def replacement(match):
            return mapping[match.group()]

        normalized_text = re.sub(r'\b\d+\b', replacement, text)
        normalized_texts.append(normalized_text)

    return normalized_texts

texts = ['Van done in 1. Hat done in 2. Ring done in 3. Desk done in 4. Sun done in', 'Ice done in 2. Snow done in 3. Watch done in 4. Sun done in 5. Table done in', 'Ring done in 3. Moon done in 4. Queen done in 5. Book done in 6. Rose done in', 'Queen done in 4. Oil done in 5. Rose done in 6. Desk done in 7. Car done in', 'Light done in 5. Arm done in 6. Road done in 7. Book done in 8. Ice done in', 'Ball done in 6. Cow done in 7. Book done in 8. Rose done in 9. Key done in', 'Road done in 7. Key done in 8. Ocean done in 9. Key done in 10. Queen done in', 'House done in 8. Rose done in 9. Key done in 10. Hat done in 11. Van done in', 'Ring done in 1. Car done in 2. Apple done in 3. Pear done in 4. Moon done in', 'Star done in 2. Sun done in 3. Road done in 4. Queen done in 5. Box done in', 'Hill done in 3. Ant done in 4. Apple done in 5. House done in 6. Hat done in', 'Chair done in 4. Van done in 5. Orange done in 6. Queen done in 7. Zip done in', 'Gate done in 5. Desk done in 6. Wolf done in 7. Rain done in 8. Flag done in', 'Queen done in 6. House done in 7. Light done in 8. Cat done in 9. Moon done in', 'Zip done in 7. Car done in 8. Ring done in 9. Hand done in 10. Fish done in', 'Snake done in 8. Queen done in 9. Window done in 10. Ear done in 11. Orange done in', 'Ice done in 1. Sand done in 2. Desk done in 3. Van done in 4. Hat done in', 'Camera done in 2. Watch done in 3. Dog done in 4. Book done in 5. Desk done in', 'Rain done in 3. Dog done in 4. Rat done in 5. Nut done in 6. Ocean done in', 'Night done in 4. Hat done in 5. Wall done in 6. Book done in 7. Tree done in', 'Gate done in 5. Chair done in 6. Ring done in 7. Hill done in 8. Car done in', 'Ax done in 6. Fan done in 7. Cat done in 8. Ring done in 9. Ring done in', 'Rose done in 7. Night done in 8. Van done in 9. Orange done in 10. Apple done in', 'Orange done in 8. Ear done in 9. Book done in 10. Ring done in 11. Bird done in', 'Ball done in 1. Wind done in 2. Wallet done in 3. Tree done in 4. Sand done in', 'Table done in 2. Jam done in 3. Apple done in 4. Pear done in 5. Ice done in', 'Gate done in 3. Train done in 4. Hat done in 5. Fan done in 6. Key done in', 'Window done in 4. Desk done in 5. Year done in 6. Van done in 7. Camera done in', 'Car done in 5. Watch done in 6. Oil done in 7. Queen done in 8. Fan done in', 'Mouse done in 6. Rose done in 7. Table done in 8. Clock done in 9. Queen done in', 'Year done in 7. Wheel done in 8. Wolf done in 9. Arm done in 10. Ax done in', 'Key done in 8. Ring done in 9. Night done in 10. Fan done in 11. Clock done in', 'Glass done in 1. Key done in 2. Nut done in 3. Rat done in 4. Van done in', 'Star done in 2. Pear done in 3. Bug done in 4. Bird done in 5. Ring done in', 'Road done in 3. Wind done in 4. Rat done in 5. Wolf done in 6. Map done in', 'Car done in 4. Ant done in 5. Rose done in 6. Van done in 7. Wolf done in', 'Zip done in 5. Hat done in 6. Wind done in 7. Rain done in 8. Car done in', 'Ring done in 6. Light done in 7. Jar done in 8. Dog done in 9. Fish done in', 'Bug done in 7. Key done in 8. Gate done in 9. Orange done in 10. Ring done in', 'Flag done in 8. Fire done in 9. Pear done in 10. Ax done in 11. Ear done in', 'Ring done in 1. Flag done in 2. Queen done in 3. Map done in 4. Camera done in', 'Desk done in 2. Fire done in 3. Desk done in 4. Road done in 5. Watch done in', 'Queen done in 3. House done in 4. Flag done in 5. Tree done in 6. Ring done in', 'Desk done in 4. Window done in 5. Fish done in 6. Jar done in 7. Hat done in', 'Snake done in 5. Key done in 6. Glass done in 7. Van done in 8. House done in', 'Camera done in 6. Year done in 7. Rose done in 8. Map done in 9. Fire done in', 'Rose done in 7. Snake done in 8. Corn done in 9. Desk done in 10. Zip done in', 'Table done in 8. Key done in 9. Eye done in 10. Van done in 11. Key done in', 'Star done in 1. Hat done in 2. Star done in 3. Eye done in 4. Gold done in', 'Gate done in 2. Queen done in 3. Camera done in 4. Zip done in 5. Ocean done in', 'Fan done in 3. Corn done in 4. Apple done in 5. Van done in 6. Cat done in', 'Key done in 4. Gold done in 5. Star done in 6. Queen done in 7. Arm done in', 'Van done in 5. Snake done in 6. Car done in 7. Star done in 8. Watch done in', 'Jar done in 6. Flag done in 7. Window done in 8. Sun done in 9. Van done in', 'Wolf done in 7. Watch done in 8. Ring done in 9. Desk done in 10. Car done in', 'Cow done in 8. Tree done in 9. Book done in 10. Wall done in 11. Flag done in', 'Van done in 1. Wall done in 2. Ring done in 3. Car done in 4. Key done in', 'Jar done in 2. Wallet done in 3. Fish done in 4. Watch done in 5. Orange done in', 'Watch done in 3. Orange done in 4. Table done in 5. Corn done in 6. Van done in', 'Lake done in 4. Star done in 5. Fan done in 6. Fan done in 7. Night done in', 'Fan done in 5. Ball done in 6. Desk done in 7. Jam done in 8. Tree done in', 'Key done in 6. Jar done in 7. Night done in 8. Fish done in 9. Fan done in', 'Ice done in 7. Rose done in 8. Wall done in 9. Road done in 10. Window done in', 'Tree done in 8. Hill done in 9. Wall done in 10. Queen done in 11. Desk done in', 'Gold done in 1. King done in 2. Queen done in 3. Desk done in 4. Night done in', 'Van done in 2. Sand done in 3. Tree done in 4. Car done in 5. Cow done in', 'Pear done in 3. Eye done in 4. Lake done in 5. Fan done in 6. Light done in', 'Jam done in 4. Road done in 5. Corn done in 6. Ice done in 7. Pen done in', 'Iron done in 5. Ring done in 6. Star done in 7. Van done in 8. Star done in', 'Bird done in 6. Wheel done in 7. Cat done in 8. Desk done in 9. Desk done in', 'Fish done in 7. Gold done in 8. King done in 9. Ax done in 10. Jam done in', 'Desk done in 8. House done in 9. Cow done in 10. Hill done in 11. Gate done in', 'Nut done in 1. Light done in 2. Sand done in 3. Wall done in 4. Key done in', 'Tree done in 2. Fan done in 3. Car done in 4. Desk done in 5. Ring done in', 'Orange done in 3. Ocean done in 4. Sun done in 5. Bug done in 6. Queen done in', 'Orange done in 4. House done in 5. Watch done in 6. Corn done in 7. Ring done in', 'Wind done in 5. Orange done in 6. Rose done in 7. Zip done in 8. Queen done in', 'Iron done in 6. Cat done in 7. Glass done in 8. Box done in 9. Rose done in', 'Clock done in 7. Zip done in 8. Cat done in 9. Snow done in 10. Ant done in', 'Rose done in 8. Ear done in 9. Rose done in 10. Rat done in 11. Orange done in', 'Road done in 1. Ring done in 2. Pen done in 3. Oil done in 4. Camera done in', 'House done in 2. Zip done in 3. Queen done in 4. Snow done in 5. Lake done in', 'Van done in 3. Tree done in 4. Wall done in 5. Rat done in 6. King done in', 'Ball done in 4. Hill done in 5. Clock done in 6. Ear done in 7. Van done in', 'Night done in 5. Ice done in 6. Apple done in 7. Tree done in 8. House done in', 'Clock done in 6. Orange done in 7. Queen done in 8. Desk done in 9. Arm done in', 'Map done in 7. Sun done in 8. Clock done in 9. Cat done in 10. Ball done in', 'Desk done in 8. Key done in 9. Star done in 10. Cow done in 11. Rose done in', 'Ring done in 1. Fan done in 2. Window done in 3. Tree done in 4. Chair done in', 'House done in 2. Nut done in 3. Queen done in 4. Zip done in 5. Rose done in', 'Window done in 3. Gate done in 4. Zip done in 5. Key done in 6. Snow done in', 'Corn done in 4. Ice done in 5. Eye done in 6. Light done in 7. Desk done in', 'Hill done in 5. Snake done in 6. Orange done in 7. Road done in 8. Flag done in', 'Queen done in 6. Window done in 7. Zip done in 8. Cow done in 9. Fire done in', 'Star done in 7. Hat done in 8. Chair done in 9. Car done in 10. Ring done in', 'Desk done in 8. Watch done in 9. Desk done in 10. Ax done in 11. Queen done in', 'Train done in 1. Snow done in 2. Cow done in 3. Ring done in 4. Queen done in', 'Window done in 2. Pen done in 3. Ax done in 4. Iron done in 5. Nut done in', 'Desk done in 3. Flag done in 4. Fan done in 5. Hat done in 6. Chair done in', 'King done in 4. Star done in 5. Cow done in 6. Wallet done in 7. Fan done in', 'Star done in 5. Watch done in 6. Car done in 7. Van done in 8. Queen done in']

normalized = normalize_numerals(texts)
texts = [t + " [MASK]" for t in normalized]


target_token = '5'
distractor_token = '4'
def get_logits(model, tokenizer, texts):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)
    with torch.no_grad():
        outputs = model(**inputs)
    logits = outputs.logits
    return logits, inputs, mask_token_index


def compute_logit_diff(logits, input_ids, mask_token_index, tokenizer):
    diffs = []
    for i, (b, pos) in enumerate(zip(*mask_token_index)):
        logits_slice = logits[b, pos]
        correct_logit = logits_slice[tokenizer.convert_tokens_to_ids(target_token)]
        incorrect_logit = logits_slice[tokenizer.convert_tokens_to_ids(distractor_token)]
        diffs.append((correct_logit - incorrect_logit).item())
    return np.mean(diffs)


def get_ablation_hook(head_idx):
    def ablate_head(module, input, output):
        if isinstance(output, tuple):
            attn_output = output[0]
            attn_output[:, head_idx] = 0
            return (attn_output,) + output[1:]
        else:
            output[:, head_idx] = 0
            return output
    return ablate_head


def calculate_head_impacts(model, tokenizer, name='model'):
    model_type = 'distilbert' if 'distilbert' in name.lower() else 'bert'
    logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
    baseline_diff = compute_logit_diff(logits, inputs.input_ids, mask_token_index, tokenizer)
    print(f"{name} baseline logit difference: {baseline_diff:.4f}")
    head_impacts = []

    num_layers = model.config.num_hidden_layers
    num_heads = model.config.num_attention_heads

    for layer in range(num_layers):
        for head in range(num_heads):
            if model_type == 'bert':
                module = model.bert.encoder.layer[layer].attention.self
            else:
                module = model.distilbert.transformer.layer[layer].attention

            hook = module.register_forward_hook(get_ablation_hook(head))
            logits_ablated, _, _ = get_logits(model, tokenizer, texts)
            ablated_diff = compute_logit_diff(logits_ablated, inputs.input_ids, mask_token_index, tokenizer)
            impact_pct = max(0, min(100, 100 * (1 - ablated_diff / baseline_diff))) if baseline_diff != 0 else 0
            head_impacts.append(((layer, head), impact_pct))
            hook.remove()

    head_impacts.sort(key=lambda x: -x[1])
    return head_impacts[:10]


def get_attention_weights(model, tokenizer, top_heads, name='model'):
    model_type = 'distilbert' if 'distilbert' in name.lower() else 'bert'
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    with torch.no_grad():
        outputs = model(**inputs, output_attentions=True)
    attentions = outputs.attentions

    head_weights = {}
    for layer, head in top_heads:
        attn_tensor = attentions[layer]
        head_tensor = attn_tensor[:, head]
        head_weights[(layer, head)] = head_tensor.flatten(1).mean(0)
    return head_weights


def compare_heads_by_cosine_similarity(teacher_weights, student_weights):
    matches = {}
    for t_head, t_vec in teacher_weights.items():
        best_sim = -1
        best_match = None
        for s_head, s_vec in student_weights.items():
            sim = cosine_similarity(t_vec.unsqueeze(0), s_vec.unsqueeze(0)).item()
            if sim > best_sim:
                best_sim = sim
                best_match = (s_head, sim)
        matches[t_head] = best_match
    return matches

teacher_impacts = calculate_head_impacts(teacher, tokenizer_t, name="Teacher (BERT)")
student_impacts = calculate_head_impacts(student, tokenizer_s, name="Student (DistilBERT)")

top_teacher_heads = [h for h, _ in teacher_impacts]
top_student_heads = [h for h, _ in student_impacts]


teacher_attn = get_attention_weights(teacher, tokenizer_t, top_teacher_heads, name="Teacher")
student_attn = get_attention_weights(student, tokenizer_s, top_student_heads, name="Student")

head_matches = compare_heads_by_cosine_similarity(teacher_attn, student_attn)

print("\nTop 10 most impactful heads - Teacher (BERT):")
for (layer, head), impact in teacher_impacts:
    print(f"Layer {layer}, Head {head} -> Impact: {impact:.2f}%")

print("\nTop 10 most impactful heads - Student (DistilBERT):")
for (layer, head), impact in student_impacts:
    print(f"Layer {layer}, Head {head} -> Impact: {impact:.2f}%")

print("\nBest matching student head for each top teacher head (based on cosine similarity of attention weights):")
for t_head, (s_head, sim) in head_matches.items():
    print(f"Teacher Head {t_head} → Student Head {s_head} | Cosine Sim: {sim:.4f}")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Teacher (BERT) baseline logit difference: 1.1650
# Student (DistilBERT) baseline logit difference: 0.4904
#
# Top 10 most impactful heads - Teacher (BERT):
# Layer 1, Head 11 -> Impact: 12.35%
# Layer 6, Head 9 -> Impact: 10.83%
# Layer 9, Head 0 -> Impact: 10.46%
# Layer 1, Head 6 -> Impact: 8.87%
# Layer 7, Head 9 -> Impact: 8.83%
# Layer 0, Head 4 -> Impact: 8.26%
# Layer 4, Head 2 -> Impact: 6.57%
# Layer 7, Head 10 -> Impact: 6.27%
# Layer 4, Head 7 -> Impact: 5.80%
# Layer 1, Head 9 -> Impact: 5.56%
#
# Top 10 most impactful heads - Student (DistilBERT):
# Layer 1, Head 9 -> Impact: 100.00%
# Layer 2, Head 9 -> Impact: 89.08%
# Layer 4, Head 9 -> Impact: 55.42%
# Layer 1, Head 4 -> Impact: 53.18%
# Layer 2, Head 8 -> Impact: 53.01%
# Layer 2, Head 10 -> Impact: 49.57%
# Layer 1, Head 8 -> Impact: 44.53%
# Layer 0, Head 0 -> Impact: 44.34%
# Layer 2, Head 4 -> Impact: 38.09%
# Layer 3, Head 9 -> Impact: 27.81%
#
# Best matching student head for each top teacher head (based on cosine similarity of attention weights):
# Teacher Head (1, 11) → Student Head (0, 0) | Cosine Sim: 0.4206
# Teacher Head (6, 9) → Student Head (2, 10) | Cosine Sim: 0.8351
# Teacher Head (9, 0) → Student Head (2, 4) | Cosine Sim: 0.7405
# Teacher Head (1, 6) → Student Head (1, 4) | Cosine Sim: 0.5305
# Teacher Head (7, 9) → Student Head (3, 9) | Cosine Sim: 0.9337
# Teacher Head (0, 4) → Student Head (2, 4) | Cosine Sim: 0.8088
# Teacher Head (4, 2) → Student Head (3, 9) | Cosine Sim: 0.7866
# Teacher Head (7, 10) → Student Head (2, 8) | Cosine Sim: 0.8183
# Teacher Head (4, 7) → Student Head (3, 9) | Cosine Sim: 0.9025
# Teacher Head (1, 9) → Student Head (1, 4) | Cosine Sim: 0.7176

# %% [markdown]
# ## Visualise heads

# %%
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.patches as mpatches
from transformers import AutoModel, AutoTokenizer

device = "cuda" if torch.cuda.is_available() else "cpu"

teacher_str = "bert-base-uncased"
student_str = "distilbert-base-uncased"
teacher = AutoModel.from_pretrained(teacher_str).to(device)
student = AutoModel.from_pretrained(student_str).to(device)
tokenizer_t = AutoTokenizer.from_pretrained(teacher_str)
tokenizer_s = AutoTokenizer.from_pretrained(student_str)
teacher.eval()
student.eval()

def extract_qk(model, inputs, model_name="teacher"):
    qk_cache = {}
    def make_hook(layer_idx, head_type):
        def hook(module, input, output):
            qk_cache[f"{head_type}_{layer_idx}"] = output.detach()
        return hook
    hooks = []
    if model_name == "teacher":
        for i, layer in enumerate(model.encoder.layer):
            hooks.append(layer.attention.self.query.register_forward_hook(make_hook(i, "q")))
            hooks.append(layer.attention.self.key.register_forward_hook(make_hook(i, "k")))
    elif model_name == "student":
        for i, layer in enumerate(model.transformer.layer):
            hooks.append(layer.attention.q_lin.register_forward_hook(make_hook(i, "q")))
            hooks.append(layer.attention.k_lin.register_forward_hook(make_hook(i, "k")))
    with torch.no_grad():
        _ = model(**inputs)
    for hook in hooks:
        hook.remove()
    return qk_cache

def extract_qk_for_dataset(model, tokenizer, texts, model_name="teacher", layer_idx=0):
    num_heads = model.config.num_attention_heads
    qk_accumulator = None
    count = 0
    first_input_tokens = None

    for idx, text in enumerate(texts):
        inputs = tokenizer(text, return_tensors="pt").to(device)

        if idx == 0:
            first_input_tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])

        qk_cache = extract_qk(model, inputs, model_name)
        qk_scores = get_qk_scores_for_layer(qk_cache, layer_idx=layer_idx, num_heads=num_heads)  # FIXED

        if qk_accumulator is None:
            qk_accumulator = qk_scores
        else:
            qk_accumulator += qk_scores
        count += 1

    avg_qk_scores = qk_accumulator / count
    return avg_qk_scores, first_input_tokens



def compute_qk_scores(q, k, num_heads):
    batch_size, seq_len, hidden_dim = q.shape
    head_dim = hidden_dim // num_heads
    q = q.view(batch_size, seq_len, num_heads, head_dim).transpose(1, 2)
    k = k.view(batch_size, seq_len, num_heads, head_dim).transpose(1, 2)
    return torch.matmul(q, k.transpose(-2, -1))

def get_qk_scores_for_layer(qk_cache, layer_idx, num_heads):
    q = qk_cache[f"q_{layer_idx}"]
    k = qk_cache[f"k_{layer_idx}"]
    return compute_qk_scores(q, k, num_heads)

def plot_qk_matrix(
    qk_scores,
    tokens,
    model_name,
    layer,
    head,
    highlight_coords=None,
    vmin=0.0,
    vmax=0.3,
    show_values=False,
    trim_sep=True
):
    qk_matrix = qk_scores[0, head]
    qk_np = qk_matrix.detach().cpu().numpy()

    tokens = [tok for tok in tokens if tok != '<|endoftext|>']

    if trim_sep and tokens and tokens[-1] == '[SEP]':
        tokens = tokens[:-1]
        qk_np = qk_np[:-1, :-1]

    mask = np.triu(np.ones_like(qk_np, dtype=bool), k=1)

    plt.figure(figsize=(10, 8))
    ax = sns.heatmap(
        qk_np,
        xticklabels=tokens,
        yticklabels=tokens,
        cmap='inferno',
        linewidths=0.1,
        linecolor='white',
        annot=show_values,
        fmt='.2f',
        mask=mask,
        vmin=vmin,
        vmax=vmax
    )

    ax.set_xlabel("Key", fontsize=16, fontweight='bold')
    ax.set_ylabel("Query", fontsize=16, fontweight='bold')
    plt.xticks(rotation=90, fontsize=8)
    plt.yticks(fontsize=8)

    if highlight_coords:
        for (q_idx, k_idx) in highlight_coords:
            if q_idx < len(tokens) and k_idx < len(tokens):
                rect = mpatches.Rectangle(
                    (k_idx, q_idx), 1, 1,
                    linewidth=2.5,
                    edgecolor='red',
                    facecolor='none'
                )
                ax.add_patch(rect)

    plt.tight_layout()
    plt.show()

def visualize_avg_qk(model_type="teacher", layer_idx=0, head_idx=0, texts=None, highlight_coords=None, vmin=0.0, vmax=2.5):
    if model_type == "teacher":
        model = teacher
        tokenizer = tokenizer_t
        model_name = "teacher"
    elif model_type == "student":
        model = student
        tokenizer = tokenizer_s
        model_name = "student"
    else:
        raise ValueError("model_type must be 'teacher' or 'student'")

    texts = texts or [
        "Van done in 1. Hat done in 2. Ring done in 3. Desk done in 4. Sun done in",
        "Oil lost in 4. Apple lost in 5. Tree lost in 6. Snow lost in 7. Apple lost in",
        "Marcus born in 1. Victoria born in 2. George born in 3. Brandon born in 4. Jamie born in",
        'Ice done in 2. Snow done in 3. Watch done in 4. Sun done in 5. Table done in',
        'Ring done in 3. Moon done in 4. Queen done in 5. Book done in 6. Rose done in',
        'Queen done in 4. Oil done in 5. Rose done in 6. Desk done in 7. Car done in',
        'Light done in 5. Arm done in 6. Road done in 7. Book done in 8. Ice done in',
        'Ball done in 6. Cow done in 7. Book done in 8. Rose done in 9. Key done in',
        'Road done in 7. Key done in 8. Ocean done in 9. Key done in 10. Queen done in',
        'House done in 8. Rose done in 9. Key done in 10. Hat done in 11. Van done in',
        'Ring done in 1. Car done in 2. Apple done in 3. Pear done in 4. Moon done in',
        'Star done in 2. Sun done in 3. Road done in 4. Queen done in 5. Box done in',
    ]

    normalized = normalize_numerals(texts)
    #texts = [t + " [MASK]" for t in normalized]
    texts = normalized

    avg_qk_scores, label_tokens = extract_qk_for_dataset(
        model, tokenizer, texts, model_name, layer_idx=layer_idx
    )

    plot_qk_matrix(
        avg_qk_scores,
        label_tokens,
        model_name,
        layer_idx,
        head_idx,
        highlight_coords,
        vmin,
        vmax
    )

# %%
def find_top_heads_for_token_targets(
    model,
    tokenizer,
    texts,
    numerals=["1", "2", "3", "4"],
    model_name="teacher",
    top_n=5
):
    num_layers = model.config.num_hidden_layers
    num_heads = model.config.num_attention_heads

    inputs = tokenizer(texts[0], return_tensors="pt").to(device)
    tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])

    qk_cache = extract_qk(model, inputs, model_name)
    top_scores = []

    final_token_idx = len(tokens) - 1
    numeral_indices = [i for i, tok in enumerate(tokens) if tok in numerals]

    for layer_idx in range(num_layers):
        qk_scores = get_qk_scores_for_layer(qk_cache, layer_idx, num_heads)[0]

        for head_idx in range(num_heads):
            attn_matrix = qk_scores[head_idx]
            values = [attn_matrix[final_token_idx, k].item() for k in numeral_indices]
            avg_score = np.mean(values) if values else 0.0
            top_scores.append(((layer_idx, head_idx), avg_score))

    top_scores.sort(key=lambda x: x[1], reverse=True)
    return top_scores[:top_n], tokens, numeral_indices, final_token_idx

top_heads, tokens, numeral_indices, final_idx = find_top_heads_for_token_targets(
    model=teacher,
    tokenizer=tokenizer_t,
    texts=normalized,
    model_name="teacher"
)

print("Top heads attending from final token to numerals:")
for (layer, head), score in top_heads:
    print(f"Layer {layer}, Head {head} — Score: {score:.4f}")


top_heads, tokens, four_indices, final_idx = find_top_heads_for_token_targets(
    model=teacher,
    tokenizer=tokenizer_t,
    texts=normalized,
    model_name="teacher",
    top_n=5,
    numerals=["4"]
)

print("Top heads attending from the final token to token '4':")
for (layer, head), score in top_heads:
    print(f"Layer {layer}, Head {head} — Score: {score:.4f}")
# Out:
# Top heads attending from final token to numerals:
# Layer 0, Head 0 — Score: 18.3056
# Layer 0, Head 3 — Score: 14.0152
# Layer 4, Head 0 — Score: 13.3635
# Layer 3, Head 4 — Score: 8.7048
# Layer 2, Head 8 — Score: 8.5255
# Top heads attending from the final token to token '4':
# Layer 0, Head 0 — Score: 17.4756
# Layer 0, Head 3 — Score: 15.2846
# Layer 2, Head 11 — Score: 14.4705
# Layer 4, Head 0 — Score: 14.3825
# Layer 2, Head 1 — Score: 12.7842

# %% [markdown]
# ## Compare heads

# %% [markdown]
# ### Similar Member Detection

# %%
visualize_avg_qk("teacher", layer_idx=1, head_idx=11, highlight_coords=[(7, 2), (8, 3), (9, 4), (12, 2), (13, 3), (14, 4), (12, 7), (13, 8), (14, 9), (17, 2), (18, 3), (19, 4), (17, 7), (18, 8), (19, 9), (17, 12), (18, 13), (19, 14), (22, 2), (23, 3), (22, 7), (23, 8), (22, 12), (23, 13), (22, 17), (23, 18)], vmin=0.5, vmax=75)

# %% [markdown]
# ### Numeral Movers

# %%
visualize_avg_qk("teacher", layer_idx=4, head_idx=0, highlight_coords=[(23, 2), (23, 4), (23, 7), (23, 9), (23, 12), (23, 14), (23, 17), (23, 19)], vmin=0, vmax=65)
visualize_avg_qk("student", layer_idx=0, head_idx=0, highlight_coords=[(23, 3), (23, 4), (23, 5), (23, 8), (23, 9), (23, 10), (23, 13), (23, 14), (23, 15), (23, 18), (23, 19), (23, 20)], vmin=0, vmax=10)

# %% [markdown]
# ### Numeral Detectors

# %%
visualize_avg_qk("teacher", layer_idx=4, head_idx=2, highlight_coords=[(9, 4), (10,5), (14, 4), (15, 5), (14, 9), (15, 10), (19, 4), (20, 5), (19, 9), (20, 10), (19, 14), (20, 15)], vmin=0, vmax=15)
visualize_avg_qk("student", layer_idx=1, head_idx=9, highlight_coords=[(9, 5), (14, 10), (19, 15)], vmin=0, vmax=60)

# %% [markdown]
# ## Compute MLP influences and compare MLPs

# %%
from transformers import BertForMaskedLM, DistilBertForMaskedLM

teacher = BertForMaskedLM.from_pretrained('bert-base-uncased').to(device)
student = DistilBertForMaskedLM.from_pretrained('distilbert-base-uncased').to(device)


def get_logits(model, tokenizer, texts):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)
    with torch.no_grad():
        outputs = model(**inputs, return_dict=True)
    if hasattr(outputs, 'logits'):
        logits = outputs.logits
    else:
        raise ValueError(
            f"Expected logits from model output, got: {type(outputs)} with keys {list(outputs.keys())}. "
            f"Ensure you are using the *full MLM model*, not just the encoder."
        )
    return logits, inputs, mask_token_index




def get_mlp_ablation_hook():
    def ablate_mlp(module, input, output):
        return torch.zeros_like(output)
    return ablate_mlp


def calculate_mlp_impacts(model, tokenizer, name='model'):
    model_type = 'distilbert' if 'distilbert' in name.lower() else 'bert'
    logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
    baseline_diff = compute_logit_diff(logits, inputs.input_ids, mask_token_index, tokenizer)
    print(f"{name} baseline logit difference: {baseline_diff:.4f}")
    mlp_impacts = []

    num_layers = model.config.num_hidden_layers

    for layer in range(num_layers):
        if model_type == 'bert':
            module = model.bert.encoder.layer[layer].intermediate.dense
        else:
            module = model.distilbert.transformer.layer[layer].ffn.lin1

        hook = module.register_forward_hook(get_mlp_ablation_hook())

        try:
            logits_ablated, _, _ = get_logits(model, tokenizer, texts)
            ablated_diff = compute_logit_diff(logits_ablated, inputs.input_ids, mask_token_index, tokenizer)
            impact_pct = max(0, min(100, 100 * (1 - ablated_diff / baseline_diff))) if baseline_diff != 0 else 0
            mlp_impacts.append((layer, impact_pct))
        except Exception as e:
            print(f"Error in layer {layer}: {e}")
        finally:
            hook.remove()

    mlp_impacts.sort(key=lambda x: -x[1])
    return mlp_impacts[:10]



def get_mlp_outputs(model, tokenizer, top_layers, name='model'):
    model_type = 'distilbert' if 'distilbert' in name.lower() else 'bert'
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    with torch.no_grad():
        outputs = model(**inputs, output_hidden_states=True, return_dict=True)
    hidden_states = outputs.hidden_states

    mlp_outputs = {}
    for layer in top_layers:
        mlp_tensor = hidden_states[layer + 1]
        mlp_outputs[layer] = mlp_tensor.mean(dim=1).flatten()
    return mlp_outputs



def compare_mlps_by_cosine_similarity(teacher_outputs, student_outputs):
    matches = {}
    for t_layer, t_vec in teacher_outputs.items():
        best_sim = -1
        best_match = None
        for s_layer, s_vec in student_outputs.items():
            sim = cosine_similarity(t_vec.unsqueeze(0), s_vec.unsqueeze(0)).item()
            if sim > best_sim:
                best_sim = sim
                best_match = (s_layer, sim)
        matches[t_layer] = best_match
    return matches

teacher_mlp_impacts = calculate_mlp_impacts(teacher, tokenizer_t, name="Teacher (BERT)")
student_mlp_impacts = calculate_mlp_impacts(student, tokenizer_s, name="Student (DistilBERT)")

top_teacher_mlps = [layer for layer, _ in teacher_mlp_impacts]
top_student_mlps = [layer for layer, _ in student_mlp_impacts]

teacher_mlp_outputs = get_mlp_outputs(teacher, tokenizer_t, top_teacher_mlps, name="Teacher")
student_mlp_outputs = get_mlp_outputs(student, tokenizer_s, top_student_mlps, name="Student")

mlp_matches = compare_mlps_by_cosine_similarity(teacher_mlp_outputs, student_mlp_outputs)

print("\nTop 10 most impactful MLP layers - Teacher (BERT):")
for layer, impact in teacher_mlp_impacts:
    print(f"Layer {layer} -> Impact: {impact:.2f}%")

print("\nTop 10 most impactful MLP layers - Student (DistilBERT):")
for layer, impact in student_mlp_impacts:
    print(f"Layer {layer} -> Impact: {impact:.2f}%")

print("\nBest matching student MLP layer for each top teacher MLP layer (based on cosine similarity of outputs):")
for t_layer, (s_layer, sim) in mlp_matches.items():
    print(f"Teacher Layer {t_layer} → Student Layer {s_layer} | Cosine Sim: {sim:.4f}")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Teacher (BERT) baseline logit difference: 1.1650
# Student (DistilBERT) baseline logit difference: 0.4904
#
# Top 10 most impactful MLP layers - Teacher (BERT):
# Layer 4 -> Impact: 100.00%
# Layer 5 -> Impact: 100.00%
# Layer 10 -> Impact: 92.34%
# Layer 6 -> Impact: 84.35%
# Layer 8 -> Impact: 78.13%
# Layer 11 -> Impact: 76.68%
# Layer 3 -> Impact: 73.86%
# Layer 7 -> Impact: 70.95%
# Layer 9 -> Impact: 66.13%
# Layer 0 -> Impact: 48.34%
#
# Top 10 most impactful MLP layers - Student (DistilBERT):
# Layer 0 -> Impact: 100.00%
# Layer 1 -> Impact: 100.00%
# Layer 2 -> Impact: 100.00%
# Layer 3 -> Impact: 100.00%
# Layer 4 -> Impact: 100.00%
# Layer 5 -> Impact: 4.98%
#
# Best matching student MLP layer for each top teacher MLP layer (based on cosine similarity of outputs):
# Teacher Layer 4 → Student Layer 2 | Cosine Sim: 0.8678
# Teacher Layer 5 → Student Layer 2 | Cosine Sim: 0.8496
# Teacher Layer 10 → Student Layer 4 | Cosine Sim: 0.9363
# Teacher Layer 6 → Student Layer 2 | Cosine Sim: 0.8415
# Teacher Layer 8 → Student Layer 3 | Cosine Sim: 0.8755
# Teacher Layer 11 → Student Layer 5 | Cosine Sim: 0.9284
# Teacher Layer 3 → Student Layer 1 | Cosine Sim: 0.8629
# Teacher Layer 7 → Student Layer 3 | Cosine Sim: 0.8643
# Teacher Layer 9 → Student Layer 4 | Cosine Sim: 0.8934
# Teacher Layer 0 → Student Layer 0 | Cosine Sim: 0.8904

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
import torch

def plot_mlp_pca_by_token_position(
    teacher,
    student,
    tokenizer_t,
    tokenizer_s,
    texts,
    teacher_layer,
    student_layer,
    label_t=None,
    label_s=None,
    label_first_token=True
):
    inputs_t = tokenizer_t(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    inputs_s = tokenizer_s(texts, return_tensors='pt', padding=True, truncation=True).to(device)

    with torch.no_grad():
        teacher_outputs = teacher(**inputs_t, output_hidden_states=True, return_dict=True)
        student_outputs = student(**inputs_s, output_hidden_states=True, return_dict=True)

    teacher_activations = teacher_outputs.hidden_states[teacher_layer + 1]
    student_activations = student_outputs.hidden_states[student_layer + 1]

    seq_len = min(teacher_activations.shape[1], student_activations.shape[1])

    teacher_means = [teacher_activations[:, i, :].mean(dim=0).cpu().numpy() for i in range(seq_len)]
    student_means = [student_activations[:, i, :].mean(dim=0).cpu().numpy() for i in range(seq_len)]

    all_means = np.vstack([teacher_means, student_means])
    pca = PCA(n_components=2)
    projected = pca.fit_transform(all_means)

    proj_teacher = projected[:seq_len]
    proj_student = projected[seq_len:]

    plt.figure(figsize=(10, 7))

    idxs = range(1, seq_len) if label_first_token else range(seq_len)
    plt.scatter(proj_teacher[idxs, 0], proj_teacher[idxs, 1], color='blue', label=label_t or f"Teacher (MLP{teacher_layer})")
    plt.scatter(proj_student[idxs, 0], proj_student[idxs, 1], color='green', label=label_s or f"Student (MLP{student_layer})")

    if label_first_token:
        plt.scatter(proj_teacher[0, 0], proj_teacher[0, 1], color='red', marker='o')
        plt.annotate("0", (proj_teacher[0, 0], proj_teacher[0, 1]), color='red', fontsize=10, weight='bold')

        plt.scatter(proj_student[0, 0], proj_student[0, 1], color='red', marker='o')
        plt.annotate("0", (proj_student[0, 0], proj_student[0, 1]), color='red', fontsize=10, weight='bold')

    plt.xlabel("PCA Component 1")
    plt.ylabel("PCA Component 2")
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ### MLPT4 / MLPS4:

# %%
plot_mlp_pca_by_token_position(
    teacher=teacher,
    student=student,
    tokenizer_t=tokenizer_t,
    tokenizer_s=tokenizer_s,
    texts=texts,
    teacher_layer=4,
    student_layer=2
)

# %% [markdown]
# ### MLPT5 / MLPS2:

# %%
plot_mlp_pca_by_token_position(
    teacher=teacher,
    student=student,
    tokenizer_t=tokenizer_t,
    tokenizer_s=tokenizer_s,
    texts=texts,
    teacher_layer=5,
    student_layer=2
)

# %% [markdown]
# ### MLPT10 / MLPS4:

# %%
plot_mlp_pca_by_token_position(
    teacher=teacher,
    student=student,
    tokenizer_t=tokenizer_t,
    tokenizer_s=tokenizer_s,
    texts=texts,
    teacher_layer=10,
    student_layer=4
)

# %% [markdown]
# ### MLPT6 / MLPS2:

# %%
plot_mlp_pca_by_token_position(
    teacher=teacher,
    student=student,
    tokenizer_t=tokenizer_t,
    tokenizer_s=tokenizer_s,
    texts=texts,
    teacher_layer=6,
    student_layer=2,
    label_first_token=False
)

# %% [markdown]
# ### MLPT8 / MLPS3:

# %%
plot_mlp_pca_by_token_position(
    teacher=teacher,
    student=student,
    tokenizer_t=tokenizer_t,
    tokenizer_s=tokenizer_s,
    texts=texts,
    teacher_layer=8,
    student_layer=3
)

# %% [markdown]
# ### MLPT11 / MLPS5:

# %%
plot_mlp_pca_by_token_position(
    teacher=teacher,
    student=student,
    tokenizer_t=tokenizer_t,
    tokenizer_s=tokenizer_s,
    texts=texts,
    teacher_layer=11,
    student_layer=5,
    label_first_token=False
)

# %% [markdown]
# ### MLPT3 / MLPS1:

# %%
plot_mlp_pca_by_token_position(
    teacher=teacher,
    student=student,
    tokenizer_t=tokenizer_t,
    tokenizer_s=tokenizer_s,
    texts=texts,
    teacher_layer=3,
    student_layer=1
)

# %% [markdown]
# ### MLPT7 / MLPS3:

# %%
plot_mlp_pca_by_token_position(
    teacher=teacher,
    student=student,
    tokenizer_t=tokenizer_t,
    tokenizer_s=tokenizer_s,
    texts=texts,
    teacher_layer=7,
    student_layer=3
)

# %% [markdown]
# ### MLPT9 / MLPS4:

# %%
plot_mlp_pca_by_token_position(
    teacher=teacher,
    student=student,
    tokenizer_t=tokenizer_t,
    tokenizer_s=tokenizer_s,
    texts=texts,
    teacher_layer=9,
    student_layer=4
)

# %% [markdown]
# ### MLPT0 / MLPS0:

# %%
plot_mlp_pca_by_token_position(
    teacher=teacher,
    student=student,
    tokenizer_t=tokenizer_t,
    tokenizer_s=tokenizer_s,
    texts=texts,
    teacher_layer=0,
    student_layer=0
)

# %% [markdown]
# ## Plot performance change per component:

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.nn.functional import cosine_similarity
from transformers import BertForMaskedLM, DistilBertForMaskedLM

device = "cuda" if torch.cuda.is_available() else "cpu"

teacher = BertForMaskedLM.from_pretrained('bert-base-uncased').to(device)
student = DistilBertForMaskedLM.from_pretrained('distilbert-base-uncased').to(device)

def get_logits(model, tokenizer, texts):
    inputs = tokenizer(texts, return_tensors='pt', padding=True, truncation=True).to(device)
    mask_token_index = (inputs.input_ids == tokenizer.mask_token_id).nonzero(as_tuple=True)
    with torch.no_grad():
        outputs = model(**inputs, return_dict=True)
    logits = outputs.logits
    return logits, inputs, mask_token_index

def compute_logit_diff(logits, input_ids, mask_token_index, tokenizer):
    diffs = []
    for i, (b, pos) in enumerate(zip(*mask_token_index)):
        logits_slice = logits[b, pos]
        correct_logit = logits_slice[tokenizer.convert_tokens_to_ids(target_token)]
        incorrect_logit = logits_slice[tokenizer.convert_tokens_to_ids(distractor_token)]
        diffs.append((correct_logit - incorrect_logit).item())
    return np.mean(diffs)

def get_ablation_hook(head_idx):
    def ablate_head(module, input, output):
        if isinstance(output, tuple):
            attn_output = output[0]
            attn_output[:, head_idx] = 0
            return (attn_output,) + output[1:]
        else:
            output[:, head_idx] = 0
            return output
    return ablate_head

def calculate_head_impacts(model, tokenizer, name='model'):
    model_type = 'distilbert' if 'distilbert' in name.lower() else 'bert'
    logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
    baseline_diff = compute_logit_diff(logits, inputs.input_ids, mask_token_index, tokenizer)
    print(f"{name} baseline logit difference: {baseline_diff:.4f}")
    head_impacts = []

    num_layers = model.config.num_hidden_layers
    num_heads = model.config.num_attention_heads

    for layer in range(num_layers):
        for head in range(num_heads):
            if model_type == 'bert':
                module = model.bert.encoder.layer[layer].attention.self
            else:
                module = model.distilbert.transformer.layer[layer].attention

            hook = module.register_forward_hook(get_ablation_hook(head))
            logits_ablated, _, _ = get_logits(model, tokenizer, texts)
            ablated_diff = compute_logit_diff(logits_ablated, inputs.input_ids, mask_token_index, tokenizer)
            impact_pct = max(0, min(100, 100 * (1 - ablated_diff / baseline_diff))) if baseline_diff != 0 else 0
            head_impacts.append(((layer, head), impact_pct))
            hook.remove()

    head_impacts.sort(key=lambda x: -x[1])
    return head_impacts

def get_mlp_ablation_hook():
    def ablate_mlp(module, input, output):
        return torch.zeros_like(output)
    return ablate_mlp

def calculate_mlp_impacts(model, tokenizer, name='model'):
    model_type = 'distilbert' if 'distilbert' in name.lower() else 'bert'
    logits, inputs, mask_token_index = get_logits(model, tokenizer, texts)
    baseline_diff = compute_logit_diff(logits, inputs.input_ids, mask_token_index, tokenizer)
    print(f"{name} baseline logit difference: {baseline_diff:.4f}")
    mlp_impacts = []

    num_layers = model.config.num_hidden_layers

    for layer in range(num_layers):
        if model_type == 'bert':
            module = model.bert.encoder.layer[layer].intermediate.dense
        else:
            module = model.distilbert.transformer.layer[layer].ffn.lin1

        hook = module.register_forward_hook(get_mlp_ablation_hook())

        try:
            logits_ablated, _, _ = get_logits(model, tokenizer, texts)
            ablated_diff = compute_logit_diff(logits_ablated, inputs.input_ids, mask_token_index, tokenizer)
            impact_pct = max(0, min(100, 100 * (1 - ablated_diff / baseline_diff))) if baseline_diff != 0 else 0
            mlp_impacts.append((layer, impact_pct))
        except Exception as e:
            print(f"Error in layer {layer}: {e}")
        finally:
            hook.remove()

    mlp_impacts.sort(key=lambda x: -x[1])
    return mlp_impacts

def plot_combined_component_impacts(teacher_heads, teacher_mlp, student_heads, student_mlp):
    def get_raw(impact_list):
        return [round(impact, 2) for (_, impact) in impact_list]

    teacher_head_impacts = get_raw(teacher_heads)
    teacher_mlp_impacts = get_raw(teacher_mlp)
    student_head_impacts = get_raw(student_heads)
    student_mlp_impacts = get_raw(student_mlp)

    bins = range(0, 101, 5)

    for model_name, head_vals, mlp_vals in [
        ("Teacher", teacher_head_impacts, teacher_mlp_impacts),
        ("Student", student_head_impacts, student_mlp_impacts)
    ]:
        plt.figure(figsize=(7, 5))

        count_heads, _, _ = plt.hist(head_vals, bins=bins, alpha=0.7, label='Heads', color='orange', edgecolor='black')
        count_mlp, _, _ = plt.hist(mlp_vals, bins=bins, alpha=0.7, label='MLPs', color='blue', edgecolor='black')

        def annotate_bars(counts, bins, color):
            for count, left in zip(counts, bins[:-1]):
                if count > 0:
                    plt.text(left + 2.5, count + 0.5, str(int(count)), ha='center', fontsize=8, color=color)

        annotate_bars(count_heads, bins, 'darkorange')
        annotate_bars(count_mlp, bins, 'navy')

        plt.title(f"Distribution of Component Performance Drop Percentages ({model_name})")
        plt.xlabel("Percentage Drop from Full Performance")
        plt.ylabel("Number of Components")
        plt.legend()
        plt.tight_layout()
        plt.grid(False)
        plt.show()

def plot_all_component_drops_combined(impacts, model_name="Model"):
    drops = [-round(impact, 2) for (_, impact) in impacts]

    bins = range(-100, 1, 5)
    plt.figure(figsize=(7, 5))

    orange_hex = "#ff7f0e"

    counts, bin_edges, patches = plt.hist(
        drops, bins=bins, color=orange_hex, edgecolor='black'
    )

    for count, edge in zip(counts, bin_edges[:-1]):
        if count > 0:
            plt.text(edge + 2.5, count + 0.5, str(int(count)),
                     ha='center', fontsize=12, fontweight='bold', color='black')

    plt.xlabel("Percentage Drop from Full Performance", fontsize=14)
    plt.ylabel("Number of Components", fontsize=14)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(False)
    plt.tight_layout()
    plt.show()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
teacher_all_components = teacher_all_heads + teacher_mlp_impacts
plot_all_component_drops_combined(teacher_all_components, model_name="Teacher")

student_all_components = student_all_heads + student_mlp_impacts
plot_all_component_drops_combined(student_all_components, model_name="Student")
